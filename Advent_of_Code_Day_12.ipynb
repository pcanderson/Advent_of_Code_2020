# %% [markdown]
# # --- Day 12: Rain Risk ---
#
# Your ferry made decent progress toward the island, but the storm came in faster than anyone expected. The ferry needs to take evasive actions!
#
# Unfortunately, the ship's navigation computer seems to be malfunctioning; rather than giving a route directly to safety, it produced extremely circuitous instructions. When the captain uses the PA system to ask if anyone can help, you quickly volunteer.
#
# The navigation instructions (your puzzle input) consists of a sequence of single-character actions paired with integer input values. After staring at them for a few minutes, you work out what they probably mean:
#
#     Action N means to move north by the given value.
#     Action S means to move south by the given value.
#     Action E means to move east by the given value.
#     Action W means to move west by the given value.
#     Action L means to turn left the given number of degrees.
#     Action R means to turn right the given number of degrees.
#     Action F means to move forward by the given value in the direction the ship is currently facing.
#
# The ship starts by facing east. Only the L and R actions change the direction the ship is facing. (That is, if the ship is facing east and the next instruction is N10, the ship would move north 10 units, but would still move east if the following action were F.)
#
# For example:
#
#     F10
#     N3
#     F7
#     R90
#     F11
#
# These instructions would be handled as follows:
#
#     F10 would move the ship 10 units east (because the ship starts by facing east) to east 10, north 0.
#     N3 would move the ship 3 units north to east 10, north 3.
#     F7 would move the ship another 7 units east (because the ship is still facing east) to east 17, north 3.
#     R90 would cause the ship to turn right by 90 degrees and face south; it remains at east 17, north 3.
#     F11 would move the ship 11 units south to east 17, south 8.
#
# At the end of these instructions, the ship's Manhattan distance (sum of the absolute values of its east/west position and its north/south position) from its starting position is 17 + 8 = 25.
#
# Figure out where the navigation instructions lead. What is the Manhattan distance between that location and the ship's starting position?

# %%
import re
import math

with open("day12_input.txt") as f:
    directions = f.readlines()
direction_list = [line.strip() for line in directions]

pos_x = 0
pos_y = 0
heading = 0

reg = '^([a-zA-Z]{1})([0-9]+)$'
rg = re.compile(reg)
for direction in direction_list:
    m = rg.search(direction)
    if m:
        if m.group(1).upper() == 'N':
            pos_y += int(m.group(2))
        elif m.group(1).upper() == 'S':
            pos_y -= int(m.group(2))
        elif m.group(1).upper() == 'E':
            pos_x += int(m.group(2))
        elif m.group(1).upper() == 'W':
            pos_x -= int(m.group(2))
        elif m.group(1).upper() == 'L':
            heading += int(m.group(2))
            heading = heading % 360
        elif m.group(1).upper() == 'R':
            heading -= int(m.group(2))
            heading = heading % 360
        elif m.group(1).upper() == 'F':
            pos_x += int(m.group(2)) * int(math.cos(math.radians(heading)))
            pos_y += int(m.group(2)) * int(math.sin(math.radians(heading)))
        print(f"{m.group(1)} {m.group(2)}")
        print(f"X: {pos_x}, Y: {pos_y}, rot: {heading}")
    else:
        print(f"Error! Direction: {direction}")
        
manhattan = abs(pos_x) + abs(pos_y)
print(f"Manhattan: {manhattan}")
# Out:
# F 12
# X: 12, Y: 0, rot: 0
# W 1
# X: 11, Y: 0, rot: 0
# N 3
# X: 11, Y: 3, rot: 0
# E 3
# X: 14, Y: 3, rot: 0
# W 3
# X: 11, Y: 3, rot: 0
# F 93
# X: 104, Y: 3, rot: 0
# N 2
# X: 104, Y: 5, rot: 0
# R 90
# X: 104, Y: 5, rot: 270
# N 4
# X: 104, Y: 9, rot: 270
# L 180
# X: 104, Y: 9, rot: 90
# F 13
# X: 104, Y: 22, rot: 90
# E 2
# X: 106, Y: 22, rot: 90
# R 270
# X: 106, Y: 22, rot: 180
# F 16
# X: 90, Y: 22, rot: 180
# S 4
# X: 90, Y: 18, rot: 180
# L 90
# X: 90, Y: 18, rot: 270
# E 1
# X: 91, Y: 18, rot: 270
# S 4
# X: 91, Y: 14, rot: 270
# R 180
# X: 91, Y: 14, rot: 90
# L 90
# X: 91, Y: 14, rot: 180
# S 2
# X: 91, Y: 12, rot: 180
# F 89
# X: 2, Y: 12, rot: 180
# S 3
# X: 2, Y: 9, rot: 180
# R 90
# X: 2, Y: 9, rot: 90
# W 1
# X: 1, Y: 9, rot: 90
# F 2
# X: 1, Y: 11, rot: 90
# S 2
# X: 1, Y: 9, rot: 90
# W 3
# X: -2, Y: 9, rot: 90
# R 180
# X: -2, Y: 9, rot: 270
# N 2
# X: -2, Y: 11, rot: 270
# F 41
# X: -2, Y: -30, rot: 270
# E 3
# X: 1, Y: -30, rot: 270
# F 74
# X: 1, Y: -104, rot: 270
# E 1
# X: 2, Y: -104, rot: 270
# F 20
# X: 2, Y: -124, rot: 270
# W 3
# X: -1, Y: -124, rot: 270
# F 32
# X: -1, Y: -156, rot: 270
# E 1
# X: 0, Y: -156, rot: 270
# R 90
# X: 0, Y: -156, rot: 180
# F 19
# X: -19, Y: -156, rot: 180
# S 4
# X: -19, Y: -160, rot: 180
# E 1
# X: -18, Y: -160, rot: 180
# F 41
# X: -59, Y: -160, rot: 180
# L 180
# X: -59, Y: -160, rot: 0
# S 1
# X: -59, Y: -161, rot: 0
# L 90
# X: -59, Y: -161, rot: 90
# E 5
# X: -54, Y: -161, rot: 90
# L 90
# X: -54, Y: -161, rot: 180
# W 2
# X: -56, Y: -161, rot: 180
# F 45
# X: -101, Y: -161, rot: 180
# R 180
# X: -101, Y: -161, rot: 0
# F 17
# X: -84, Y: -161, rot: 0
# S 3
# X: -84, Y: -164, rot: 0
# E 2
# X: -82, Y: -164, rot: 0
# S 1
# X: -82, Y: -165, rot: 0
# F 27
# X: -55, Y: -165, rot: 0
# N 5
# X: -55, Y: -160, rot: 0
# R 180
# X: -55, Y: -160, rot: 180
# S 1
# X: -55, Y: -161, rot: 180
# E 5
# X: -50, Y: -161, rot: 180
# N 1
# X: -50, Y: -160, rot: 180
# L 270
# X: -50, Y: -160, rot: 90
# F 60
# X: -50, Y: -100, rot: 90
# L 180
# X: -50, Y: -100, rot: 270
# F 18
# X: -50, Y: -118, rot: 270
# N 2
# X: -50, Y: -116, rot: 270
# R 180
# X: -50, Y: -116, rot: 90
# E 4
# X: -46, Y: -116, rot: 90
# S 4
# X: -46, Y: -120, rot: 90
# L 180
# X: -46, Y: -120, rot: 270
# S 5
# X: -46, Y: -125, rot: 270
# L 270
# X: -46, Y: -125, rot: 180
# S 1
# X: -46, Y: -126, rot: 180
# F 32
# X: -78, Y: -126, rot: 180
# S 5
# X: -78, Y: -131, rot: 180
# F 83
# X: -161, Y: -131, rot: 180
# N 2
# X: -161, Y: -129, rot: 180
# R 180
# X: -161, Y: -129, rot: 0
# W 1
# X: -162, Y: -129, rot: 0
# L 180
# X: -162, Y: -129, rot: 180
# E 2
# X: -160, Y: -129, rot: 180
# S 3
# X: -160, Y: -132, rot: 180
# F 94
# X: -254, Y: -132, rot: 180
# N 3
# X: -254, Y: -129, rot: 180
# F 82
# X: -336, Y: -129, rot: 180
# L 90
# X: -336, Y: -129, rot: 270
# N 2
# X: -336, Y: -127, rot: 270
# W 5
# X: -341, Y: -127, rot: 270
# R 180
# X: -341, Y: -127, rot: 90
# S 4
# X: -341, Y: -131, rot: 90
# W 3
# X: -344, Y: -131, rot: 90
# E 1
# X: -343, Y: -131, rot: 90
# F 81
# X: -343, Y: -50, rot: 90
# S 3
# X: -343, Y: -53, rot: 90
# F 45
# X: -343, Y: -8, rot: 90
# R 90
# X: -343, Y: -8, rot: 0
# F 51
# X: -292, Y: -8, rot: 0
# R 180
# X: -292, Y: -8, rot: 180
# N 1
# X: -292, Y: -7, rot: 180
# W 5
# X: -297, Y: -7, rot: 180
# L 90
# X: -297, Y: -7, rot: 270
# E 3
# X: -294, Y: -7, rot: 270
# N 5
# X: -294, Y: -2, rot: 270
# E 3
# X: -291, Y: -2, rot: 270
# R 180
# X: -291, Y: -2, rot: 90
# N 3
# X: -291, Y: 1, rot: 90
# R 180
# X: -291, Y: 1, rot: 270
# F 87
# X: -291, Y: -86, rot: 270
# E 4
# X: -287, Y: -86, rot: 270
# R 90
# X: -287, Y: -86, rot: 180
# E 4
# X: -283, Y: -86, rot: 180
# L 180
# X: -283, Y: -86, rot: 0
# E 4
# X: -279, Y: -86, rot: 0
# R 90
# X: -279, Y: -86, rot: 270
# N 1
# X: -279, Y: -85, rot: 270
# L 270
# X: -279, Y: -85, rot: 180
# N 3
# X: -279, Y: -82, rot: 180
# E 3
# X: -276, Y: -82, rot: 180
# E 3
# X: -273, Y: -82, rot: 180
# L 180
# X: -273, Y: -82, rot: 0
# N 1
# X: -273, Y: -81, rot: 0
# W 5
# X: -278, Y: -81, rot: 0
# N 3
# X: -278, Y: -78, rot: 0
# F 85
# X: -193, Y: -78, rot: 0
# N 1
# X: -193, Y: -77, rot: 0
# E 2
# X: -191, Y: -77, rot: 0
# S 3
# X: -191, Y: -80, rot: 0
# L 90
# X: -191, Y: -80, rot: 90
# E 5
# X: -186, Y: -80, rot: 90
# N 3
# X: -186, Y: -77, rot: 90
# N 1
# X: -186, Y: -76, rot: 90
# F 74
# X: -186, Y: -2, rot: 90
# W 2
# X: -188, Y: -2, rot: 90
# F 79
# X: -188, Y: 77, rot: 90
# S 1
# X: -188, Y: 76, rot: 90
# L 90
# X: -188, Y: 76, rot: 180
# W 5
# X: -193, Y: 76, rot: 180
# F 88
# X: -281, Y: 76, rot: 180
# W 4
# X: -285, Y: 76, rot: 180
# N 1
# X: -285, Y: 77, rot: 180
# R 180
# X: -285, Y: 77, rot: 0
# F 94
# X: -191, Y: 77, rot: 0
# L 90
# X: -191, Y: 77, rot: 90
# W 5
# X: -196, Y: 77, rot: 90
# F 79
# X: -196, Y: 156, rot: 90
# R 180
# X: -196, Y: 156, rot: 270
# R 270
# X: -196, Y: 156, rot: 0
# N 3
# X: -196, Y: 159, rot: 0
# F 83
# X: -113, Y: 159, rot: 0
# W 3
# X: -116, Y: 159, rot: 0
# N 3
# X: -116, Y: 162, rot: 0
# L 90
# X: -116, Y: 162, rot: 90
# F 33
# X: -116, Y: 195, rot: 90
# S 5
# X: -116, Y: 190, rot: 90
# F 93
# X: -116, Y: 283, rot: 90
# L 90
# X: -116, Y: 283, rot: 180
# S 1
# X: -116, Y: 282, rot: 180
# W 3
# X: -119, Y: 282, rot: 180
# F 24
# X: -143, Y: 282, rot: 180
# L 90
# X: -143, Y: 282, rot: 270
# F 80
# X: -143, Y: 202, rot: 270
# S 2
# X: -143, Y: 200, rot: 270
# F 86
# X: -143, Y: 114, rot: 270
# F 7
# X: -143, Y: 107, rot: 270
# R 90
# X: -143, Y: 107, rot: 180
# E 1
# X: -142, Y: 107, rot: 180
# S 3
# X: -142, Y: 104, rot: 180
# W 3
# X: -145, Y: 104, rot: 180
# F 23
# X: -168, Y: 104, rot: 180
# R 90
# X: -168, Y: 104, rot: 90
# S 1
# X: -168, Y: 103, rot: 90
# W 4
# X: -172, Y: 103, rot: 90
# R 90
# X: -172, Y: 103, rot: 0
# N 4
# X: -172, Y: 107, rot: 0
# R 270
# X: -172, Y: 107, rot: 90
# S 1
# X: -172, Y: 106, rot: 90
# E 1
# X: -171, Y: 106, rot: 90
# F 20
# X: -171, Y: 126, rot: 90
# L 270
# X: -171, Y: 126, rot: 0
# F 31
# X: -140, Y: 126, rot: 0
# S 2
# X: -140, Y: 124, rot: 0
# L 180
# X: -140, Y: 124, rot: 180
# F 41
# X: -181, Y: 124, rot: 180
# E 3
# X: -178, Y: 124, rot: 180
# L 90
# X: -178, Y: 124, rot: 270
# N 3
# X: -178, Y: 127, rot: 270
# E 3
# X: -175, Y: 127, rot: 270
# N 1
# X: -175, Y: 128, rot: 270
# E 5
# X: -170, Y: 128, rot: 270
# F 27
# X: -170, Y: 101, rot: 270
# S 3
# X: -170, Y: 98, rot: 270
# W 2
# X: -172, Y: 98, rot: 270
# L 90
# X: -172, Y: 98, rot: 0
# E 5
# X: -167, Y: 98, rot: 0
# S 1
# X: -167, Y: 97, rot: 0
# F 9
# X: -158, Y: 97, rot: 0
# S 3
# X: -158, Y: 94, rot: 0
# E 2
# X: -156, Y: 94, rot: 0
# R 90
# X: -156, Y: 94, rot: 270
# S 5
# X: -156, Y: 89, rot: 270
# E 2
# X: -154, Y: 89, rot: 270
# R 180
# X: -154, Y: 89, rot: 90
# E 3
# X: -151, Y: 89, rot: 90
# F 32
# X: -151, Y: 121, rot: 90
# E 3
# X: -148, Y: 121, rot: 90
# S 1
# X: -148, Y: 120, rot: 90
# W 1
# X: -149, Y: 120, rot: 90
# F 39
# X: -149, Y: 159, rot: 90
# N 4
# X: -149, Y: 163, rot: 90
# F 5
# X: -149, Y: 168, rot: 90
# E 5
# X: -144, Y: 168, rot: 90
# F 26
# X: -144, Y: 194, rot: 90
# W 4
# X: -148, Y: 194, rot: 90
# S 1
# X: -148, Y: 193, rot: 90
# F 54
# X: -148, Y: 247, rot: 90
# S 5
# X: -148, Y: 242, rot: 90
# R 90
# X: -148, Y: 242, rot: 0
# F 50
# X: -98, Y: 242, rot: 0
# W 4
# X: -102, Y: 242, rot: 0
# S 1
# X: -102, Y: 241, rot: 0
# L 90
# X: -102, Y: 241, rot: 90
# S 5
# X: -102, Y: 236, rot: 90
# L 90
# X: -102, Y: 236, rot: 180
# F 2
# X: -104, Y: 236, rot: 180
# E 5
# X: -99, Y: 236, rot: 180
# L 90
# X: -99, Y: 236, rot: 270
# N 1
# X: -99, Y: 237, rot: 270
# W 3
# X: -102, Y: 237, rot: 270
# F 75
# X: -102, Y: 162, rot: 270
# L 90
# X: -102, Y: 162, rot: 0
# F 85
# X: -17, Y: 162, rot: 0
# S 2
# X: -17, Y: 160, rot: 0
# W 4
# X: -21, Y: 160, rot: 0
# F 93
# X: 72, Y: 160, rot: 0
# S 4
# X: 72, Y: 156, rot: 0
# E 3
# X: 75, Y: 156, rot: 0
# S 2
# X: 75, Y: 154, rot: 0
# E 4
# X: 79, Y: 154, rot: 0
# R 90
# X: 79, Y: 154, rot: 270
# S 3
# X: 79, Y: 151, rot: 270
# W 1
# X: 78, Y: 151, rot: 270
# F 94
# X: 78, Y: 57, rot: 270
# R 90
# X: 78, Y: 57, rot: 180
# N 3
# X: 78, Y: 60, rot: 180
# R 270
# X: 78, Y: 60, rot: 270
# S 2
# X: 78, Y: 58, rot: 270
# W 3
# X: 75, Y: 58, rot: 270
# N 5
# X: 75, Y: 63, rot: 270
# F 1
# X: 75, Y: 62, rot: 270
# S 1
# X: 75, Y: 61, rot: 270
# F 32
# X: 75, Y: 29, rot: 270
# E 2
# X: 77, Y: 29, rot: 270
# F 17
# X: 77, Y: 12, rot: 270
# N 4
# X: 77, Y: 16, rot: 270
# W 2
# X: 75, Y: 16, rot: 270
# S 4
# X: 75, Y: 12, rot: 270
# L 90
# X: 75, Y: 12, rot: 0
# W 2
# X: 73, Y: 12, rot: 0
# N 2
# X: 73, Y: 14, rot: 0
# L 180
# X: 73, Y: 14, rot: 180
# F 94
# X: -21, Y: 14, rot: 180
# R 90
# X: -21, Y: 14, rot: 90
# F 78
# X: -21, Y: 92, rot: 90
# N 3
# X: -21, Y: 95, rot: 90
# E 3
# X: -18, Y: 95, rot: 90
# N 3
# X: -18, Y: 98, rot: 90
# E 4
# X: -14, Y: 98, rot: 90
# F 37
# X: -14, Y: 135, rot: 90
# E 5
# X: -9, Y: 135, rot: 90
# L 180
# X: -9, Y: 135, rot: 270
# W 2
# X: -11, Y: 135, rot: 270
# L 180
# X: -11, Y: 135, rot: 90
# N 2
# X: -11, Y: 137, rot: 90
# R 270
# X: -11, Y: 137, rot: 180
# S 2
# X: -11, Y: 135, rot: 180
# F 28
# X: -39, Y: 135, rot: 180
# R 90
# X: -39, Y: 135, rot: 90
# S 1
# X: -39, Y: 134, rot: 90
# F 15
# X: -39, Y: 149, rot: 90
# E 1
# X: -38, Y: 149, rot: 90
# F 50
# X: -38, Y: 199, rot: 90
# N 3
# X: -38, Y: 202, rot: 90
# R 90
# X: -38, Y: 202, rot: 0
# F 14
# X: -24, Y: 202, rot: 0
# N 4
# X: -24, Y: 206, rot: 0
# F 80
# X: 56, Y: 206, rot: 0
# L 90
# X: 56, Y: 206, rot: 90
# S 5
# X: 56, Y: 201, rot: 90
# W 1
# X: 55, Y: 201, rot: 90
# L 90
# X: 55, Y: 201, rot: 180
# W 5
# X: 50, Y: 201, rot: 180
# F 100
# X: -50, Y: 201, rot: 180
# N 1
# X: -50, Y: 202, rot: 180
# L 90
# X: -50, Y: 202, rot: 270
# N 5
# X: -50, Y: 207, rot: 270
# W 2
# X: -52, Y: 207, rot: 270
# N 1
# X: -52, Y: 208, rot: 270
# F 76
# X: -52, Y: 132, rot: 270
# L 180
# X: -52, Y: 132, rot: 90
# S 3
# X: -52, Y: 129, rot: 90
# L 180
# X: -52, Y: 129, rot: 270
# E 1
# X: -51, Y: 129, rot: 270
# E 5
# X: -46, Y: 129, rot: 270
# F 1
# X: -46, Y: 128, rot: 270
# R 90
# X: -46, Y: 128, rot: 180
# W 4
# X: -50, Y: 128, rot: 180
# F 95
# X: -145, Y: 128, rot: 180
# S 2
# X: -145, Y: 126, rot: 180
# R 90
# X: -145, Y: 126, rot: 90
# W 2
# X: -147, Y: 126, rot: 90
# F 29
# X: -147, Y: 155, rot: 90
# W 2
# X: -149, Y: 155, rot: 90
# F 47
# X: -149, Y: 202, rot: 90
# W 5
# X: -154, Y: 202, rot: 90
# S 5
# X: -154, Y: 197, rot: 90
# W 4
# X: -158, Y: 197, rot: 90
# F 58
# X: -158, Y: 255, rot: 90
# L 90
# X: -158, Y: 255, rot: 180
# F 22
# X: -180, Y: 255, rot: 180
# N 1
# X: -180, Y: 256, rot: 180
# E 4
# X: -176, Y: 256, rot: 180
# N 4
# X: -176, Y: 260, rot: 180
# E 2
# X: -174, Y: 260, rot: 180
# S 5
# X: -174, Y: 255, rot: 180
# L 180
# X: -174, Y: 255, rot: 0
# W 4
# X: -178, Y: 255, rot: 0
# N 2
# X: -178, Y: 257, rot: 0
# W 3
# X: -181, Y: 257, rot: 0
# R 90
# X: -181, Y: 257, rot: 270
# F 76
# X: -181, Y: 181, rot: 270
# N 1
# X: -181, Y: 182, rot: 270
# F 41
# X: -181, Y: 141, rot: 270
# W 5
# X: -186, Y: 141, rot: 270
# F 48
# X: -186, Y: 93, rot: 270
# W 1
# X: -187, Y: 93, rot: 270
# N 4
# X: -187, Y: 97, rot: 270
# E 2
# X: -185, Y: 97, rot: 270
# R 180
# X: -185, Y: 97, rot: 90
# F 79
# X: -185, Y: 176, rot: 90
# N 1
# X: -185, Y: 177, rot: 90
# L 90
# X: -185, Y: 177, rot: 180
# S 4
# X: -185, Y: 173, rot: 180
# E 2
# X: -183, Y: 173, rot: 180
# F 86
# X: -269, Y: 173, rot: 180
# N 2
# X: -269, Y: 175, rot: 180
# E 1
# X: -268, Y: 175, rot: 180
# F 5
# X: -273, Y: 175, rot: 180
# W 4
# X: -277, Y: 175, rot: 180
# S 2
# X: -277, Y: 173, rot: 180
# L 90
# X: -277, Y: 173, rot: 270
# F 3
# X: -277, Y: 170, rot: 270
# R 270
# X: -277, Y: 170, rot: 0
# F 43
# X: -234, Y: 170, rot: 0
# L 180
# X: -234, Y: 170, rot: 180
# S 5
# X: -234, Y: 165, rot: 180
# R 90
# X: -234, Y: 165, rot: 90
# W 5
# X: -239, Y: 165, rot: 90
# R 180
# X: -239, Y: 165, rot: 270
# E 4
# X: -235, Y: 165, rot: 270
# S 3
# X: -235, Y: 162, rot: 270
# R 90
# X: -235, Y: 162, rot: 180
# S 2
# X: -235, Y: 160, rot: 180
# F 41
# X: -276, Y: 160, rot: 180
# F 70
# X: -346, Y: 160, rot: 180
# L 270
# X: -346, Y: 160, rot: 90
# E 4
# X: -342, Y: 160, rot: 90
# R 90
# X: -342, Y: 160, rot: 0
# F 18
# X: -324, Y: 160, rot: 0
# S 4
# X: -324, Y: 156, rot: 0
# F 88
# X: -236, Y: 156, rot: 0
# E 2
# X: -234, Y: 156, rot: 0
# L 90
# X: -234, Y: 156, rot: 90
# L 270
# X: -234, Y: 156, rot: 0
# F 56
# X: -178, Y: 156, rot: 0
# L 90
# X: -178, Y: 156, rot: 90
# N 1
# X: -178, Y: 157, rot: 90
# L 90
# X: -178, Y: 157, rot: 180
# F 7
# X: -185, Y: 157, rot: 180
# S 3
# X: -185, Y: 154, rot: 180
# F 36
# X: -221, Y: 154, rot: 180
# L 90
# X: -221, Y: 154, rot: 270
# F 2
# X: -221, Y: 152, rot: 270
# L 90
# X: -221, Y: 152, rot: 0
# F 2
# X: -219, Y: 152, rot: 0
# W 4
# X: -223, Y: 152, rot: 0
# S 4
# X: -223, Y: 148, rot: 0
# L 90
# X: -223, Y: 148, rot: 90
# E 5
# X: -218, Y: 148, rot: 90
# N 2
# X: -218, Y: 150, rot: 90
# L 90
# X: -218, Y: 150, rot: 180
# S 4
# X: -218, Y: 146, rot: 180
# R 90
# X: -218, Y: 146, rot: 90
# W 1
# X: -219, Y: 146, rot: 90
# R 90
# X: -219, Y: 146, rot: 0
# N 2
# X: -219, Y: 148, rot: 0
# E 3
# X: -216, Y: 148, rot: 0
# W 2
# X: -218, Y: 148, rot: 0
# S 4
# X: -218, Y: 144, rot: 0
# E 4
# X: -214, Y: 144, rot: 0
# R 90
# X: -214, Y: 144, rot: 270
# N 5
# X: -214, Y: 149, rot: 270
# L 90
# X: -214, Y: 149, rot: 0
# N 4
# X: -214, Y: 153, rot: 0
# F 55
# X: -159, Y: 153, rot: 0
# N 3
# X: -159, Y: 156, rot: 0
# E 1
# X: -158, Y: 156, rot: 0
# F 80
# X: -78, Y: 156, rot: 0
# W 2
# X: -80, Y: 156, rot: 0
# R 90
# X: -80, Y: 156, rot: 270
# S 2
# X: -80, Y: 154, rot: 270
# L 90
# X: -80, Y: 154, rot: 0
# W 5
# X: -85, Y: 154, rot: 0
# R 90
# X: -85, Y: 154, rot: 270
# R 90
# X: -85, Y: 154, rot: 180
# F 87
# X: -172, Y: 154, rot: 180
# L 270
# X: -172, Y: 154, rot: 90
# S 5
# X: -172, Y: 149, rot: 90
# R 270
# X: -172, Y: 149, rot: 180
# N 5
# X: -172, Y: 154, rot: 180
# E 5
# X: -167, Y: 154, rot: 180
# F 10
# X: -177, Y: 154, rot: 180
# E 1
# X: -176, Y: 154, rot: 180
# R 180
# X: -176, Y: 154, rot: 0
# N 1
# X: -176, Y: 155, rot: 0
# L 90
# X: -176, Y: 155, rot: 90
# S 3
# X: -176, Y: 152, rot: 90
# W 1
# X: -177, Y: 152, rot: 90
# F 18
# X: -177, Y: 170, rot: 90
# R 90
# X: -177, Y: 170, rot: 0
# S 3
# X: -177, Y: 167, rot: 0
# F 89
# X: -88, Y: 167, rot: 0
# L 90
# X: -88, Y: 167, rot: 90
# F 42
# X: -88, Y: 209, rot: 90
# S 3
# X: -88, Y: 206, rot: 90
# R 180
# X: -88, Y: 206, rot: 270
# F 92
# X: -88, Y: 114, rot: 270
# L 90
# X: -88, Y: 114, rot: 0
# F 48
# X: -40, Y: 114, rot: 0
# F 11
# X: -29, Y: 114, rot: 0
# W 2
# X: -31, Y: 114, rot: 0
# L 180
# X: -31, Y: 114, rot: 180
# F 27
# X: -58, Y: 114, rot: 180
# L 180
# X: -58, Y: 114, rot: 0
# N 3
# X: -58, Y: 117, rot: 0
# W 1
# X: -59, Y: 117, rot: 0
# S 2
# X: -59, Y: 115, rot: 0
# L 90
# X: -59, Y: 115, rot: 90
# W 1
# X: -60, Y: 115, rot: 90
# N 1
# X: -60, Y: 116, rot: 90
# W 4
# X: -64, Y: 116, rot: 90
# N 1
# X: -64, Y: 117, rot: 90
# R 90
# X: -64, Y: 117, rot: 0
# S 2
# X: -64, Y: 115, rot: 0
# W 5
# X: -69, Y: 115, rot: 0
# E 1
# X: -68, Y: 115, rot: 0
# F 74
# X: 6, Y: 115, rot: 0
# L 180
# X: 6, Y: 115, rot: 180
# F 48
# X: -42, Y: 115, rot: 180
# W 3
# X: -45, Y: 115, rot: 180
# F 3
# X: -48, Y: 115, rot: 180
# E 3
# X: -45, Y: 115, rot: 180
# F 74
# X: -119, Y: 115, rot: 180
# L 270
# X: -119, Y: 115, rot: 90
# F 38
# X: -119, Y: 153, rot: 90
# R 180
# X: -119, Y: 153, rot: 270
# N 2
# X: -119, Y: 155, rot: 270
# F 83
# X: -119, Y: 72, rot: 270
# S 1
# X: -119, Y: 71, rot: 270
# F 78
# X: -119, Y: -7, rot: 270
# L 90
# X: -119, Y: -7, rot: 0
# N 4
# X: -119, Y: -3, rot: 0
# F 43
# X: -76, Y: -3, rot: 0
# W 3
# X: -79, Y: -3, rot: 0
# W 2
# X: -81, Y: -3, rot: 0
# N 1
# X: -81, Y: -2, rot: 0
# L 90
# X: -81, Y: -2, rot: 90
# N 2
# X: -81, Y: 0, rot: 90
# W 4
# X: -85, Y: 0, rot: 90
# L 90
# X: -85, Y: 0, rot: 180
# S 5
# X: -85, Y: -5, rot: 180
# E 5
# X: -80, Y: -5, rot: 180
# W 1
# X: -81, Y: -5, rot: 180
# F 83
# X: -164, Y: -5, rot: 180
# E 5
# X: -159, Y: -5, rot: 180
# F 70
# X: -229, Y: -5, rot: 180
# N 2
# X: -229, Y: -3, rot: 180
# L 90
# X: -229, Y: -3, rot: 270
# N 2
# X: -229, Y: -1, rot: 270
# F 66
# X: -229, Y: -67, rot: 270
# S 2
# X: -229, Y: -69, rot: 270
# E 2
# X: -227, Y: -69, rot: 270
# R 90
# X: -227, Y: -69, rot: 180
# N 1
# X: -227, Y: -68, rot: 180
# F 2
# X: -229, Y: -68, rot: 180
# L 90
# X: -229, Y: -68, rot: 270
# F 15
# X: -229, Y: -83, rot: 270
# W 3
# X: -232, Y: -83, rot: 270
# F 10
# X: -232, Y: -93, rot: 270
# R 90
# X: -232, Y: -93, rot: 180
# N 3
# X: -232, Y: -90, rot: 180
# E 5
# X: -227, Y: -90, rot: 180
# N 5
# X: -227, Y: -85, rot: 180
# F 57
# X: -284, Y: -85, rot: 180
# R 90
# X: -284, Y: -85, rot: 90
# W 2
# X: -286, Y: -85, rot: 90
# F 83
# X: -286, Y: -2, rot: 90
# F 91
# X: -286, Y: 89, rot: 90
# W 5
# X: -291, Y: 89, rot: 90
# N 2
# X: -291, Y: 91, rot: 90
# R 90
# X: -291, Y: 91, rot: 0
# E 4
# X: -287, Y: 91, rot: 0
# S 2
# X: -287, Y: 89, rot: 0
# L 90
# X: -287, Y: 89, rot: 90
# N 2
# X: -287, Y: 91, rot: 90
# R 90
# X: -287, Y: 91, rot: 0
# S 1
# X: -287, Y: 90, rot: 0
# F 49
# X: -238, Y: 90, rot: 0
# L 90
# X: -238, Y: 90, rot: 90
# E 3
# X: -235, Y: 90, rot: 90
# L 180
# X: -235, Y: 90, rot: 270
# E 2
# X: -233, Y: 90, rot: 270
# F 98
# X: -233, Y: -8, rot: 270
# S 1
# X: -233, Y: -9, rot: 270
# R 180
# X: -233, Y: -9, rot: 90
# F 23
# X: -233, Y: 14, rot: 90
# N 2
# X: -233, Y: 16, rot: 90
# E 2
# X: -231, Y: 16, rot: 90
# F 8
# X: -231, Y: 24, rot: 90
# N 2
# X: -231, Y: 26, rot: 90
# L 90
# X: -231, Y: 26, rot: 180
# E 2
# X: -229, Y: 26, rot: 180
# N 4
# X: -229, Y: 30, rot: 180
# R 90
# X: -229, Y: 30, rot: 90
# F 29
# X: -229, Y: 59, rot: 90
# L 90
# X: -229, Y: 59, rot: 180
# E 5
# X: -224, Y: 59, rot: 180
# S 3
# X: -224, Y: 56, rot: 180
# F 92
# X: -316, Y: 56, rot: 180
# S 5
# X: -316, Y: 51, rot: 180
# F 68
# X: -384, Y: 51, rot: 180
# N 1
# X: -384, Y: 52, rot: 180
# L 90
# X: -384, Y: 52, rot: 270
# S 5
# X: -384, Y: 47, rot: 270
# F 73
# X: -384, Y: -26, rot: 270
# W 4
# X: -388, Y: -26, rot: 270
# L 180
# X: -388, Y: -26, rot: 90
# S 1
# X: -388, Y: -27, rot: 90
# R 180
# X: -388, Y: -27, rot: 270
# F 74
# X: -388, Y: -101, rot: 270
# R 90
# X: -388, Y: -101, rot: 180
# F 27
# X: -415, Y: -101, rot: 180
# R 180
# X: -415, Y: -101, rot: 0
# R 90
# X: -415, Y: -101, rot: 270
# F 88
# X: -415, Y: -189, rot: 270
# R 270
# X: -415, Y: -189, rot: 0
# S 1
# X: -415, Y: -190, rot: 0
# W 1
# X: -416, Y: -190, rot: 0
# F 73
# X: -343, Y: -190, rot: 0
# W 1
# X: -344, Y: -190, rot: 0
# S 5
# X: -344, Y: -195, rot: 0
# L 90
# X: -344, Y: -195, rot: 90
# N 5
# X: -344, Y: -190, rot: 90
# R 90
# X: -344, Y: -190, rot: 0
# F 50
# X: -294, Y: -190, rot: 0
# E 2
# X: -292, Y: -190, rot: 0
# R 90
# X: -292, Y: -190, rot: 270
# W 3
# X: -295, Y: -190, rot: 270
# F 23
# X: -295, Y: -213, rot: 270
# L 90
# X: -295, Y: -213, rot: 0
# W 2
# X: -297, Y: -213, rot: 0
# N 1
# X: -297, Y: -212, rot: 0
# E 2
# X: -295, Y: -212, rot: 0
# N 2
# X: -295, Y: -210, rot: 0
# F 56
# X: -239, Y: -210, rot: 0
# L 90
# X: -239, Y: -210, rot: 90
# F 22
# X: -239, Y: -188, rot: 90
# E 5
# X: -234, Y: -188, rot: 90
# F 46
# X: -234, Y: -142, rot: 90
# S 2
# X: -234, Y: -144, rot: 90
# L 180
# X: -234, Y: -144, rot: 270
# E 4
# X: -230, Y: -144, rot: 270
# R 90
# X: -230, Y: -144, rot: 180
# F 10
# X: -240, Y: -144, rot: 180
# W 2
# X: -242, Y: -144, rot: 180
# R 90
# X: -242, Y: -144, rot: 90
# E 5
# X: -237, Y: -144, rot: 90
# L 270
# X: -237, Y: -144, rot: 0
# S 4
# X: -237, Y: -148, rot: 0
# F 55
# X: -182, Y: -148, rot: 0
# R 90
# X: -182, Y: -148, rot: 270
# F 17
# X: -182, Y: -165, rot: 270
# R 90
# X: -182, Y: -165, rot: 180
# F 8
# X: -190, Y: -165, rot: 180
# L 180
# X: -190, Y: -165, rot: 0
# F 25
# X: -165, Y: -165, rot: 0
# E 4
# X: -161, Y: -165, rot: 0
# S 2
# X: -161, Y: -167, rot: 0
# E 1
# X: -160, Y: -167, rot: 0
# S 1
# X: -160, Y: -168, rot: 0
# F 35
# X: -125, Y: -168, rot: 0
# N 5
# X: -125, Y: -163, rot: 0
# W 5
# X: -130, Y: -163, rot: 0
# N 3
# X: -130, Y: -160, rot: 0
# F 79
# X: -51, Y: -160, rot: 0
# N 1
# X: -51, Y: -159, rot: 0
# R 90
# X: -51, Y: -159, rot: 270
# E 1
# X: -50, Y: -159, rot: 270
# F 32
# X: -50, Y: -191, rot: 270
# R 90
# X: -50, Y: -191, rot: 180
# F 87
# X: -137, Y: -191, rot: 180
# N 2
# X: -137, Y: -189, rot: 180
# R 180
# X: -137, Y: -189, rot: 0
# L 180
# X: -137, Y: -189, rot: 180
# F 38
# X: -175, Y: -189, rot: 180
# L 90
# X: -175, Y: -189, rot: 270
# S 1
# X: -175, Y: -190, rot: 270
# L 270
# X: -175, Y: -190, rot: 180
# S 5
# X: -175, Y: -195, rot: 180
# F 63
# X: -238, Y: -195, rot: 180
# L 180
# X: -238, Y: -195, rot: 0
# F 50
# X: -188, Y: -195, rot: 0
# W 1
# X: -189, Y: -195, rot: 0
# F 23
# X: -166, Y: -195, rot: 0
# S 2
# X: -166, Y: -197, rot: 0
# E 2
# X: -164, Y: -197, rot: 0
# F 30
# X: -134, Y: -197, rot: 0
# E 3
# X: -131, Y: -197, rot: 0
# L 90
# X: -131, Y: -197, rot: 90
# F 79
# X: -131, Y: -118, rot: 90
# R 180
# X: -131, Y: -118, rot: 270
# F 90
# X: -131, Y: -208, rot: 270
# L 180
# X: -131, Y: -208, rot: 90
# F 81
# X: -131, Y: -127, rot: 90
# R 90
# X: -131, Y: -127, rot: 0
# F 72
# X: -59, Y: -127, rot: 0
# R 180
# X: -59, Y: -127, rot: 180
# E 4
# X: -55, Y: -127, rot: 180
# N 3
# X: -55, Y: -124, rot: 180
# W 3
# X: -58, Y: -124, rot: 180
# R 90
# X: -58, Y: -124, rot: 90
# E 5
# X: -53, Y: -124, rot: 90
# R 90
# X: -53, Y: -124, rot: 0
# F 81
# X: 28, Y: -124, rot: 0
# S 3
# X: 28, Y: -127, rot: 0
# F 66
# X: 94, Y: -127, rot: 0
# S 5
# X: 94, Y: -132, rot: 0
# F 83
# X: 177, Y: -132, rot: 0
# L 90
# X: 177, Y: -132, rot: 90
# F 15
# X: 177, Y: -117, rot: 90
# N 5
# X: 177, Y: -112, rot: 90
# F 16
# X: 177, Y: -96, rot: 90
# L 270
# X: 177, Y: -96, rot: 0
# S 3
# X: 177, Y: -99, rot: 0
# L 270
# X: 177, Y: -99, rot: 270
# S 3
# X: 177, Y: -102, rot: 270
# L 90
# X: 177, Y: -102, rot: 0
# N 5
# X: 177, Y: -97, rot: 0
# E 2
# X: 179, Y: -97, rot: 0
# F 60
# X: 239, Y: -97, rot: 0
# W 2
# X: 237, Y: -97, rot: 0
# S 4
# X: 237, Y: -101, rot: 0
# E 1
# X: 238, Y: -101, rot: 0
# R 180
# X: 238, Y: -101, rot: 180
# W 2
# X: 236, Y: -101, rot: 180
# F 28
# X: 208, Y: -101, rot: 180
# W 4
# X: 204, Y: -101, rot: 180
# R 90
# X: 204, Y: -101, rot: 90
# N 3
# X: 204, Y: -98, rot: 90
# W 3
# X: 201, Y: -98, rot: 90
# F 48
# X: 201, Y: -50, rot: 90
# W 2
# X: 199, Y: -50, rot: 90
# S 5
# X: 199, Y: -55, rot: 90
# F 2
# X: 199, Y: -53, rot: 90
# R 90
# X: 199, Y: -53, rot: 0
# F 47
# X: 246, Y: -53, rot: 0
# S 5
# X: 246, Y: -58, rot: 0
# F 11
# X: 257, Y: -58, rot: 0
# S 5
# X: 257, Y: -63, rot: 0
# E 2
# X: 259, Y: -63, rot: 0
# N 2
# X: 259, Y: -61, rot: 0
# F 93
# X: 352, Y: -61, rot: 0
# S 2
# X: 352, Y: -63, rot: 0
# E 4
# X: 356, Y: -63, rot: 0
# F 23
# X: 379, Y: -63, rot: 0
# E 4
# X: 383, Y: -63, rot: 0
# S 1
# X: 383, Y: -64, rot: 0
# L 90
# X: 383, Y: -64, rot: 90
# F 87
# X: 383, Y: 23, rot: 90
# L 180
# X: 383, Y: 23, rot: 270
# N 4
# X: 383, Y: 27, rot: 270
# W 5
# X: 378, Y: 27, rot: 270
# N 5
# X: 378, Y: 32, rot: 270
# R 180
# X: 378, Y: 32, rot: 90
# R 90
# X: 378, Y: 32, rot: 0
# S 5
# X: 378, Y: 27, rot: 0
# F 65
# X: 443, Y: 27, rot: 0
# E 5
# X: 448, Y: 27, rot: 0
# F 51
# X: 499, Y: 27, rot: 0
# E 5
# X: 504, Y: 27, rot: 0
# F 65
# X: 569, Y: 27, rot: 0
# L 90
# X: 569, Y: 27, rot: 90
# S 4
# X: 569, Y: 23, rot: 90
# W 3
# X: 566, Y: 23, rot: 90
# L 180
# X: 566, Y: 23, rot: 270
# W 1
# X: 565, Y: 23, rot: 270
# W 2
# X: 563, Y: 23, rot: 270
# E 4
# X: 567, Y: 23, rot: 270
# R 270
# X: 567, Y: 23, rot: 0
# N 4
# X: 567, Y: 27, rot: 0
# F 86
# X: 653, Y: 27, rot: 0
# R 90
# X: 653, Y: 27, rot: 270
# L 90
# X: 653, Y: 27, rot: 0
# F 9
# X: 662, Y: 27, rot: 0
# F 76
# X: 738, Y: 27, rot: 0
# N 4
# X: 738, Y: 31, rot: 0
# E 4
# X: 742, Y: 31, rot: 0
# N 4
# X: 742, Y: 35, rot: 0
# R 90
# X: 742, Y: 35, rot: 270
# F 40
# X: 742, Y: -5, rot: 270
# E 5
# X: 747, Y: -5, rot: 270
# S 1
# X: 747, Y: -6, rot: 270
# W 3
# X: 744, Y: -6, rot: 270
# F 22
# X: 744, Y: -28, rot: 270
# W 2
# X: 742, Y: -28, rot: 270
# L 90
# X: 742, Y: -28, rot: 0
# F 51
# X: 793, Y: -28, rot: 0
# W 1
# X: 792, Y: -28, rot: 0
# E 1
# X: 793, Y: -28, rot: 0
# S 2
# X: 793, Y: -30, rot: 0
# F 27
# X: 820, Y: -30, rot: 0
# S 5
# X: 820, Y: -35, rot: 0
# R 90
# X: 820, Y: -35, rot: 270
# R 270
# X: 820, Y: -35, rot: 0
# R 90
# X: 820, Y: -35, rot: 270
# F 71
# X: 820, Y: -106, rot: 270
# R 90
# X: 820, Y: -106, rot: 180
# W 4
# X: 816, Y: -106, rot: 180
# R 90
# X: 816, Y: -106, rot: 90
# W 1
# X: 815, Y: -106, rot: 90
# N 4
# X: 815, Y: -102, rot: 90
# L 90
# X: 815, Y: -102, rot: 180
# E 2
# X: 817, Y: -102, rot: 180
# E 1
# X: 818, Y: -102, rot: 180
# F 61
# X: 757, Y: -102, rot: 180
# W 1
# X: 756, Y: -102, rot: 180
# S 5
# X: 756, Y: -107, rot: 180
# E 2
# X: 758, Y: -107, rot: 180
# E 4
# X: 762, Y: -107, rot: 180
# F 10
# X: 752, Y: -107, rot: 180
# L 90
# X: 752, Y: -107, rot: 270
# N 2
# X: 752, Y: -105, rot: 270
# F 3
# X: 752, Y: -108, rot: 270
# R 90
# X: 752, Y: -108, rot: 180
# F 7
# X: 745, Y: -108, rot: 180
# L 90
# X: 745, Y: -108, rot: 270
# F 56
# X: 745, Y: -164, rot: 270
# N 1
# X: 745, Y: -163, rot: 270
# R 270
# X: 745, Y: -163, rot: 0
# F 70
# X: 815, Y: -163, rot: 0
# F 71
# X: 886, Y: -163, rot: 0
# N 3
# X: 886, Y: -160, rot: 0
# F 96
# X: 982, Y: -160, rot: 0
# R 90
# X: 982, Y: -160, rot: 270
# F 56
# X: 982, Y: -216, rot: 270
# S 4
# X: 982, Y: -220, rot: 270
# F 96
# X: 982, Y: -316, rot: 270
# S 5
# X: 982, Y: -321, rot: 270
# W 5
# X: 977, Y: -321, rot: 270
# N 4
# X: 977, Y: -317, rot: 270
# E 2
# X: 979, Y: -317, rot: 270
# F 90
# X: 979, Y: -407, rot: 270
# S 5
# X: 979, Y: -412, rot: 270
# R 180
# X: 979, Y: -412, rot: 90
# F 81
# X: 979, Y: -331, rot: 90
# E 1
# X: 980, Y: -331, rot: 90
# N 4
# X: 980, Y: -327, rot: 90
# L 90
# X: 980, Y: -327, rot: 180
# S 2
# X: 980, Y: -329, rot: 180
# L 180
# X: 980, Y: -329, rot: 0
# E 5
# X: 985, Y: -329, rot: 0
# R 90
# X: 985, Y: -329, rot: 270
# S 4
# X: 985, Y: -333, rot: 270
# F 60
# X: 985, Y: -393, rot: 270
# S 4
# X: 985, Y: -397, rot: 270
# W 3
# X: 982, Y: -397, rot: 270
# F 3
# X: 982, Y: -400, rot: 270
# E 5
# X: 987, Y: -400, rot: 270
# F 54
# X: 987, Y: -454, rot: 270
# Manhattan: 1441

# %% [markdown]
# # --- Part Two ---
#
# Before you can give the destination to the captain, you realize that the actual action meanings were printed on the back of the instructions the whole time.
#
# Almost all of the actions indicate how to move a waypoint which is relative to the ship's position:
#
#     Action N means to move the waypoint north by the given value.
#     Action S means to move the waypoint south by the given value.
#     Action E means to move the waypoint east by the given value.
#     Action W means to move the waypoint west by the given value.
#     Action L means to rotate the waypoint around the ship left (counter-clockwise) the given number of degrees.
#     Action R means to rotate the waypoint around the ship right (clockwise) the given number of degrees.
#     Action F means to move forward to the waypoint a number of times equal to the given value.
#
# The waypoint starts 10 units east and 1 unit north relative to the ship. The waypoint is relative to the ship; that is, if the ship moves, the waypoint moves with it.
#
# For example, using the same instructions as above:
#
#     F10 moves the ship to the waypoint 10 times (a total of 100 units east and 10 units north), leaving the ship at east 100, north 10. The waypoint stays 10 units east and 1 unit north of the ship.
#     N3 moves the waypoint 3 units north to 10 units east and 4 units north of the ship. The ship remains at east 100, north 10.
#     F7 moves the ship to the waypoint 7 times (a total of 70 units east and 28 units north), leaving the ship at east 170, north 38. The waypoint stays 10 units east and 4 units north of the ship.
#     R90 rotates the waypoint around the ship clockwise 90 degrees, moving it to 4 units east and 10 units south of the ship. The ship remains at east 170, north 38.
#     F11 moves the ship to the waypoint 11 times (a total of 44 units east and 110 units south), leaving the ship at east 214, south 72. The waypoint stays 4 units east and 10 units south of the ship.
#
# After these operations, the ship's Manhattan distance from its starting position is 214 + 72 = 286.
#
# Figure out where the navigation instructions actually lead. What is the Manhattan distance between that location and the ship's starting position?

# %%
import re
import math

with open("day12_input.txt") as f:
    directions = f.readlines()
direction_list = [line.strip() for line in directions]

ship_x = 0
ship_y = 0
pos_x = 10
pos_y = 1
heading = 0

reg = '^([a-zA-Z]{1})([0-9]+)$'
rg = re.compile(reg)
for direction in direction_list:
    m = rg.search(direction)
    if m:
        if m.group(1).upper() == 'N':
            pos_y += int(m.group(2))
        elif m.group(1).upper() == 'S':
            pos_y -= int(m.group(2))
        elif m.group(1).upper() == 'E':
            pos_x += int(m.group(2))
        elif m.group(1).upper() == 'W':
            pos_x -= int(m.group(2))
        elif m.group(1).upper() == 'L':
            rad = math.radians(int(m.group(2)) % 360)
            pos_x_temp = ship_x + (math.cos(rad) * (pos_x - ship_x) - math.sin(rad) * (pos_y - ship_y))
            pos_y_temp = ship_y + (math.sin(rad) * (pos_x - ship_x) + math.cos(rad) * (pos_y - ship_y))
            pos_x, pos_y = pos_x_temp, pos_y_temp
        elif m.group(1).upper() == 'R':
            rad = math.radians(-1 * int(m.group(2)) % 360)
            pos_x_temp = ship_x + (math.cos(rad) * (pos_x - ship_x) - math.sin(rad) * (pos_y - ship_y))
            pos_y_temp = ship_y + (math.sin(rad) * (pos_x - ship_x) + math.cos(rad) * (pos_y - ship_y))
            pos_x, pos_y = pos_x_temp, pos_y_temp
        elif m.group(1).upper() == 'F':
            for _ in range(0, int(m.group(2))):
                delta_x = pos_x - ship_x
                delta_y = pos_y - ship_y
                ship_x, ship_y = pos_x, pos_y
                pos_x = ship_x + delta_x
                pos_y = ship_y + delta_y
                
        print(f"{m.group(1)} {m.group(2)}")
        print(f"ShipX: {ship_x}, ShipY: {ship_y}, rot: {heading}")
        print(f"PosX: {pos_x}, PosY: {pos_y}, rot: {heading}")
    else:
        print(f"Error! Direction: {direction}")
        
manhattan = abs(ship_x) + abs(ship_y)
print(f"Manhattan: {manhattan}")
# Out:
# F 12
# ShipX: 120, ShipY: 12, rot: 0
# PosX: 130, PosY: 13, rot: 0
# W 1
# ShipX: 120, ShipY: 12, rot: 0
# PosX: 129, PosY: 13, rot: 0
# N 3
# ShipX: 120, ShipY: 12, rot: 0
# PosX: 129, PosY: 16, rot: 0
# E 3
# ShipX: 120, ShipY: 12, rot: 0
# PosX: 132, PosY: 16, rot: 0
# W 3
# ShipX: 120, ShipY: 12, rot: 0
# PosX: 129, PosY: 16, rot: 0
# F 93
# ShipX: 957, ShipY: 384, rot: 0
# PosX: 966, PosY: 388, rot: 0
# N 2
# ShipX: 957, ShipY: 384, rot: 0
# PosX: 966, PosY: 390, rot: 0
# R 90
# ShipX: 957, ShipY: 384, rot: 0
# PosX: 963.0, PosY: 375.0, rot: 0
# N 4
# ShipX: 957, ShipY: 384, rot: 0
# PosX: 963.0, PosY: 379.0, rot: 0
# L 180
# ShipX: 957, ShipY: 384, rot: 0
# PosX: 951.0, PosY: 389.0, rot: 0
# F 13
# ShipX: 879.0, ShipY: 449.0, rot: 0
# PosX: 873.0, PosY: 454.0, rot: 0
# E 2
# ShipX: 879.0, ShipY: 449.0, rot: 0
# PosX: 875.0, PosY: 454.0, rot: 0
# R 270
# ShipX: 879.0, ShipY: 449.0, rot: 0
# PosX: 874.0, PosY: 445.0, rot: 0
# F 16
# ShipX: 799.0, ShipY: 385.0, rot: 0
# PosX: 794.0, PosY: 381.0, rot: 0
# S 4
# ShipX: 799.0, ShipY: 385.0, rot: 0
# PosX: 794.0, PosY: 377.0, rot: 0
# L 90
# ShipX: 799.0, ShipY: 385.0, rot: 0
# PosX: 807.0, PosY: 380.0, rot: 0
# E 1
# ShipX: 799.0, ShipY: 385.0, rot: 0
# PosX: 808.0, PosY: 380.0, rot: 0
# S 4
# ShipX: 799.0, ShipY: 385.0, rot: 0
# PosX: 808.0, PosY: 376.0, rot: 0
# R 180
# ShipX: 799.0, ShipY: 385.0, rot: 0
# PosX: 790.0, PosY: 394.0, rot: 0
# L 90
# ShipX: 799.0, ShipY: 385.0, rot: 0
# PosX: 790.0, PosY: 376.0, rot: 0
# S 2
# ShipX: 799.0, ShipY: 385.0, rot: 0
# PosX: 790.0, PosY: 374.0, rot: 0
# F 89
# ShipX: -2.0, ShipY: -594.0, rot: 0
# PosX: -11.0, PosY: -605.0, rot: 0
# S 3
# ShipX: -2.0, ShipY: -594.0, rot: 0
# PosX: -11.0, PosY: -608.0, rot: 0
# R 90
# ShipX: -2.0, ShipY: -594.0, rot: 0
# PosX: -15.999999999999998, PosY: -585.0, rot: 0
# W 1
# ShipX: -2.0, ShipY: -594.0, rot: 0
# PosX: -17.0, PosY: -585.0, rot: 0
# F 2
# ShipX: -32.0, ShipY: -576.0, rot: 0
# PosX: -47.0, PosY: -567.0, rot: 0
# S 2
# ShipX: -32.0, ShipY: -576.0, rot: 0
# PosX: -47.0, PosY: -569.0, rot: 0
# W 3
# ShipX: -32.0, ShipY: -576.0, rot: 0
# PosX: -50.0, PosY: -569.0, rot: 0
# R 180
# ShipX: -32.0, ShipY: -576.0, rot: 0
# PosX: -14.0, PosY: -583.0, rot: 0
# N 2
# ShipX: -32.0, ShipY: -576.0, rot: 0
# PosX: -14.0, PosY: -581.0, rot: 0
# F 41
# ShipX: 706.0, ShipY: -781.0, rot: 0
# PosX: 724.0, PosY: -786.0, rot: 0
# E 3
# ShipX: 706.0, ShipY: -781.0, rot: 0
# PosX: 727.0, PosY: -786.0, rot: 0
# F 74
# ShipX: 2260.0, ShipY: -1151.0, rot: 0
# PosX: 2281.0, PosY: -1156.0, rot: 0
# E 1
# ShipX: 2260.0, ShipY: -1151.0, rot: 0
# PosX: 2282.0, PosY: -1156.0, rot: 0
# F 20
# ShipX: 2700.0, ShipY: -1251.0, rot: 0
# PosX: 2722.0, PosY: -1256.0, rot: 0
# W 3
# ShipX: 2700.0, ShipY: -1251.0, rot: 0
# PosX: 2719.0, PosY: -1256.0, rot: 0
# F 32
# ShipX: 3308.0, ShipY: -1411.0, rot: 0
# PosX: 3327.0, PosY: -1416.0, rot: 0
# E 1
# ShipX: 3308.0, ShipY: -1411.0, rot: 0
# PosX: 3328.0, PosY: -1416.0, rot: 0
# R 90
# ShipX: 3308.0, ShipY: -1411.0, rot: 0
# PosX: 3303.0, PosY: -1431.0, rot: 0
# F 19
# ShipX: 3213.0, ShipY: -1791.0, rot: 0
# PosX: 3208.0, PosY: -1811.0, rot: 0
# S 4
# ShipX: 3213.0, ShipY: -1791.0, rot: 0
# PosX: 3208.0, PosY: -1815.0, rot: 0
# E 1
# ShipX: 3213.0, ShipY: -1791.0, rot: 0
# PosX: 3209.0, PosY: -1815.0, rot: 0
# F 41
# ShipX: 3049.0, ShipY: -2775.0, rot: 0
# PosX: 3045.0, PosY: -2799.0, rot: 0
# L 180
# ShipX: 3049.0, ShipY: -2775.0, rot: 0
# PosX: 3053.0, PosY: -2751.0, rot: 0
# S 1
# ShipX: 3049.0, ShipY: -2775.0, rot: 0
# PosX: 3053.0, PosY: -2752.0, rot: 0
# L 90
# ShipX: 3049.0, ShipY: -2775.0, rot: 0
# PosX: 3026.0, PosY: -2771.0, rot: 0
# E 5
# ShipX: 3049.0, ShipY: -2775.0, rot: 0
# PosX: 3031.0, PosY: -2771.0, rot: 0
# L 90
# ShipX: 3049.0, ShipY: -2775.0, rot: 0
# PosX: 3045.0, PosY: -2793.0, rot: 0
# W 2
# ShipX: 3049.0, ShipY: -2775.0, rot: 0
# PosX: 3043.0, PosY: -2793.0, rot: 0
# F 45
# ShipX: 2779.0, ShipY: -3585.0, rot: 0
# PosX: 2773.0, PosY: -3603.0, rot: 0
# R 180
# ShipX: 2779.0, ShipY: -3585.0, rot: 0
# PosX: 2785.0, PosY: -3567.0, rot: 0
# F 17
# ShipX: 2881.0, ShipY: -3279.0, rot: 0
# PosX: 2887.0, PosY: -3261.0, rot: 0
# S 3
# ShipX: 2881.0, ShipY: -3279.0, rot: 0
# PosX: 2887.0, PosY: -3264.0, rot: 0
# E 2
# ShipX: 2881.0, ShipY: -3279.0, rot: 0
# PosX: 2889.0, PosY: -3264.0, rot: 0
# S 1
# ShipX: 2881.0, ShipY: -3279.0, rot: 0
# PosX: 2889.0, PosY: -3265.0, rot: 0
# F 27
# ShipX: 3097.0, ShipY: -2901.0, rot: 0
# PosX: 3105.0, PosY: -2887.0, rot: 0
# N 5
# ShipX: 3097.0, ShipY: -2901.0, rot: 0
# PosX: 3105.0, PosY: -2882.0, rot: 0
# R 180
# ShipX: 3097.0, ShipY: -2901.0, rot: 0
# PosX: 3089.0, PosY: -2920.0, rot: 0
# S 1
# ShipX: 3097.0, ShipY: -2901.0, rot: 0
# PosX: 3089.0, PosY: -2921.0, rot: 0
# E 5
# ShipX: 3097.0, ShipY: -2901.0, rot: 0
# PosX: 3094.0, PosY: -2921.0, rot: 0
# N 1
# ShipX: 3097.0, ShipY: -2901.0, rot: 0
# PosX: 3094.0, PosY: -2920.0, rot: 0
# L 270
# ShipX: 3097.0, ShipY: -2901.0, rot: 0
# PosX: 3078.0, PosY: -2898.0, rot: 0
# F 60
# ShipX: 1957.0, ShipY: -2721.0, rot: 0
# PosX: 1938.0, PosY: -2718.0, rot: 0
# L 180
# ShipX: 1957.0, ShipY: -2721.0, rot: 0
# PosX: 1976.0, PosY: -2724.0, rot: 0
# F 18
# ShipX: 2299.0, ShipY: -2775.0, rot: 0
# PosX: 2318.0, PosY: -2778.0, rot: 0
# N 2
# ShipX: 2299.0, ShipY: -2775.0, rot: 0
# PosX: 2318.0, PosY: -2776.0, rot: 0
# R 180
# ShipX: 2299.0, ShipY: -2775.0, rot: 0
# PosX: 2280.0, PosY: -2774.0, rot: 0
# E 4
# ShipX: 2299.0, ShipY: -2775.0, rot: 0
# PosX: 2284.0, PosY: -2774.0, rot: 0
# S 4
# ShipX: 2299.0, ShipY: -2775.0, rot: 0
# PosX: 2284.0, PosY: -2778.0, rot: 0
# L 180
# ShipX: 2299.0, ShipY: -2775.0, rot: 0
# PosX: 2314.0, PosY: -2772.0, rot: 0
# S 5
# ShipX: 2299.0, ShipY: -2775.0, rot: 0
# PosX: 2314.0, PosY: -2777.0, rot: 0
# L 270
# ShipX: 2299.0, ShipY: -2775.0, rot: 0
# PosX: 2297.0, PosY: -2790.0, rot: 0
# S 1
# ShipX: 2299.0, ShipY: -2775.0, rot: 0
# PosX: 2297.0, PosY: -2791.0, rot: 0
# F 32
# ShipX: 2235.0, ShipY: -3287.0, rot: 0
# PosX: 2233.0, PosY: -3303.0, rot: 0
# S 5
# ShipX: 2235.0, ShipY: -3287.0, rot: 0
# PosX: 2233.0, PosY: -3308.0, rot: 0
# F 83
# ShipX: 2069.0, ShipY: -5030.0, rot: 0
# PosX: 2067.0, PosY: -5051.0, rot: 0
# N 2
# ShipX: 2069.0, ShipY: -5030.0, rot: 0
# PosX: 2067.0, PosY: -5049.0, rot: 0
# R 180
# ShipX: 2069.0, ShipY: -5030.0, rot: 0
# PosX: 2071.0, PosY: -5011.0, rot: 0
# W 1
# ShipX: 2069.0, ShipY: -5030.0, rot: 0
# PosX: 2070.0, PosY: -5011.0, rot: 0
# L 180
# ShipX: 2069.0, ShipY: -5030.0, rot: 0
# PosX: 2068.0, PosY: -5049.0, rot: 0
# E 2
# ShipX: 2069.0, ShipY: -5030.0, rot: 0
# PosX: 2070.0, PosY: -5049.0, rot: 0
# S 3
# ShipX: 2069.0, ShipY: -5030.0, rot: 0
# PosX: 2070.0, PosY: -5052.0, rot: 0
# F 94
# ShipX: 2163.0, ShipY: -7098.0, rot: 0
# PosX: 2164.0, PosY: -7120.0, rot: 0
# N 3
# ShipX: 2163.0, ShipY: -7098.0, rot: 0
# PosX: 2164.0, PosY: -7117.0, rot: 0
# F 82
# ShipX: 2245.0, ShipY: -8656.0, rot: 0
# PosX: 2246.0, PosY: -8675.0, rot: 0
# L 90
# ShipX: 2245.0, ShipY: -8656.0, rot: 0
# PosX: 2264.0, PosY: -8655.0, rot: 0
# N 2
# ShipX: 2245.0, ShipY: -8656.0, rot: 0
# PosX: 2264.0, PosY: -8653.0, rot: 0
# W 5
# ShipX: 2245.0, ShipY: -8656.0, rot: 0
# PosX: 2259.0, PosY: -8653.0, rot: 0
# R 180
# ShipX: 2245.0, ShipY: -8656.0, rot: 0
# PosX: 2231.0, PosY: -8659.0, rot: 0
# S 4
# ShipX: 2245.0, ShipY: -8656.0, rot: 0
# PosX: 2231.0, PosY: -8663.0, rot: 0
# W 3
# ShipX: 2245.0, ShipY: -8656.0, rot: 0
# PosX: 2228.0, PosY: -8663.0, rot: 0
# E 1
# ShipX: 2245.0, ShipY: -8656.0, rot: 0
# PosX: 2229.0, PosY: -8663.0, rot: 0
# F 81
# ShipX: 949.0, ShipY: -9223.0, rot: 0
# PosX: 933.0, PosY: -9230.0, rot: 0
# S 3
# ShipX: 949.0, ShipY: -9223.0, rot: 0
# PosX: 933.0, PosY: -9233.0, rot: 0
# F 45
# ShipX: 229.0, ShipY: -9673.0, rot: 0
# PosX: 213.0, PosY: -9683.0, rot: 0
# R 90
# ShipX: 229.0, ShipY: -9673.0, rot: 0
# PosX: 219.0, PosY: -9657.0, rot: 0
# F 51
# ShipX: -281.0, ShipY: -8857.0, rot: 0
# PosX: -291.0, PosY: -8841.0, rot: 0
# R 180
# ShipX: -281.0, ShipY: -8857.0, rot: 0
# PosX: -271.0, PosY: -8873.0, rot: 0
# N 1
# ShipX: -281.0, ShipY: -8857.0, rot: 0
# PosX: -271.0, PosY: -8872.0, rot: 0
# W 5
# ShipX: -281.0, ShipY: -8857.0, rot: 0
# PosX: -276.0, PosY: -8872.0, rot: 0
# L 90
# ShipX: -281.0, ShipY: -8857.0, rot: 0
# PosX: -266.0, PosY: -8852.0, rot: 0
# E 3
# ShipX: -281.0, ShipY: -8857.0, rot: 0
# PosX: -263.0, PosY: -8852.0, rot: 0
# N 5
# ShipX: -281.0, ShipY: -8857.0, rot: 0
# PosX: -263.0, PosY: -8847.0, rot: 0
# E 3
# ShipX: -281.0, ShipY: -8857.0, rot: 0
# PosX: -260.0, PosY: -8847.0, rot: 0
# R 180
# ShipX: -281.0, ShipY: -8857.0, rot: 0
# PosX: -302.0, PosY: -8867.0, rot: 0
# N 3
# ShipX: -281.0, ShipY: -8857.0, rot: 0
# PosX: -302.0, PosY: -8864.0, rot: 0
# R 180
# ShipX: -281.0, ShipY: -8857.0, rot: 0
# PosX: -260.0, PosY: -8850.0, rot: 0
# F 87
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1567.0, PosY: -8241.0, rot: 0
# E 4
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1571.0, PosY: -8241.0, rot: 0
# R 90
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1553.0, PosY: -8273.0, rot: 0
# E 4
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1557.0, PosY: -8273.0, rot: 0
# L 180
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1535.0, PosY: -8223.0, rot: 0
# E 4
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1539.0, PosY: -8223.0, rot: 0
# R 90
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1571.0, PosY: -8241.0, rot: 0
# N 1
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1571.0, PosY: -8240.0, rot: 0
# L 270
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1554.0, PosY: -8273.0, rot: 0
# N 3
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1554.0, PosY: -8270.0, rot: 0
# E 3
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1557.0, PosY: -8270.0, rot: 0
# E 3
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1560.0, PosY: -8270.0, rot: 0
# L 180
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1532.0, PosY: -8226.0, rot: 0
# N 1
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1532.0, PosY: -8225.0, rot: 0
# W 5
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1527.0, PosY: -8225.0, rot: 0
# N 3
# ShipX: 1546.0, ShipY: -8248.0, rot: 0
# PosX: 1527.0, PosY: -8222.0, rot: 0
# F 85
# ShipX: -69.0, ShipY: -6038.0, rot: 0
# PosX: -88.0, PosY: -6012.0, rot: 0
# N 1
# ShipX: -69.0, ShipY: -6038.0, rot: 0
# PosX: -88.0, PosY: -6011.0, rot: 0
# E 2
# ShipX: -69.0, ShipY: -6038.0, rot: 0
# PosX: -86.0, PosY: -6011.0, rot: 0
# S 3
# ShipX: -69.0, ShipY: -6038.0, rot: 0
# PosX: -86.0, PosY: -6014.0, rot: 0
# L 90
# ShipX: -69.0, ShipY: -6038.0, rot: 0
# PosX: -93.0, PosY: -6055.0, rot: 0
# E 5
# ShipX: -69.0, ShipY: -6038.0, rot: 0
# PosX: -88.0, PosY: -6055.0, rot: 0
# N 3
# ShipX: -69.0, ShipY: -6038.0, rot: 0
# PosX: -88.0, PosY: -6052.0, rot: 0
# N 1
# ShipX: -69.0, ShipY: -6038.0, rot: 0
# PosX: -88.0, PosY: -6051.0, rot: 0
# F 74
# ShipX: -1475.0, ShipY: -7000.0, rot: 0
# PosX: -1494.0, PosY: -7013.0, rot: 0
# W 2
# ShipX: -1475.0, ShipY: -7000.0, rot: 0
# PosX: -1496.0, PosY: -7013.0, rot: 0
# F 79
# ShipX: -3134.0, ShipY: -8027.0, rot: 0
# PosX: -3155.0, PosY: -8040.0, rot: 0
# S 1
# ShipX: -3134.0, ShipY: -8027.0, rot: 0
# PosX: -3155.0, PosY: -8041.0, rot: 0
# L 90
# ShipX: -3134.0, ShipY: -8027.0, rot: 0
# PosX: -3120.0, PosY: -8048.0, rot: 0
# W 5
# ShipX: -3134.0, ShipY: -8027.0, rot: 0
# PosX: -3125.0, PosY: -8048.0, rot: 0
# F 88
# ShipX: -2342.0, ShipY: -9875.0, rot: 0
# PosX: -2333.0, PosY: -9896.0, rot: 0
# W 4
# ShipX: -2342.0, ShipY: -9875.0, rot: 0
# PosX: -2337.0, PosY: -9896.0, rot: 0
# N 1
# ShipX: -2342.0, ShipY: -9875.0, rot: 0
# PosX: -2337.0, PosY: -9895.0, rot: 0
# R 180
# ShipX: -2342.0, ShipY: -9875.0, rot: 0
# PosX: -2347.0, PosY: -9855.0, rot: 0
# F 94
# ShipX: -2812.0, ShipY: -7995.0, rot: 0
# PosX: -2817.0, PosY: -7975.0, rot: 0
# L 90
# ShipX: -2812.0, ShipY: -7995.0, rot: 0
# PosX: -2832.0, PosY: -8000.0, rot: 0
# W 5
# ShipX: -2812.0, ShipY: -7995.0, rot: 0
# PosX: -2837.0, PosY: -8000.0, rot: 0
# F 79
# ShipX: -4787.0, ShipY: -8390.0, rot: 0
# PosX: -4812.0, PosY: -8395.0, rot: 0
# R 180
# ShipX: -4787.0, ShipY: -8390.0, rot: 0
# PosX: -4762.0, PosY: -8385.0, rot: 0
# R 270
# ShipX: -4787.0, ShipY: -8390.0, rot: 0
# PosX: -4792.0, PosY: -8365.0, rot: 0
# N 3
# ShipX: -4787.0, ShipY: -8390.0, rot: 0
# PosX: -4792.0, PosY: -8362.0, rot: 0
# F 83
# ShipX: -5202.0, ShipY: -6066.0, rot: 0
# PosX: -5207.0, PosY: -6038.0, rot: 0
# W 3
# ShipX: -5202.0, ShipY: -6066.0, rot: 0
# PosX: -5210.0, PosY: -6038.0, rot: 0
# N 3
# ShipX: -5202.0, ShipY: -6066.0, rot: 0
# PosX: -5210.0, PosY: -6035.0, rot: 0
# L 90
# ShipX: -5202.0, ShipY: -6066.0, rot: 0
# PosX: -5233.0, PosY: -6074.0, rot: 0
# F 33
# ShipX: -6225.0, ShipY: -6330.0, rot: 0
# PosX: -6256.0, PosY: -6338.0, rot: 0
# S 5
# ShipX: -6225.0, ShipY: -6330.0, rot: 0
# PosX: -6256.0, PosY: -6343.0, rot: 0
# F 93
# ShipX: -9108.0, ShipY: -7539.0, rot: 0
# PosX: -9139.0, PosY: -7552.0, rot: 0
# L 90
# ShipX: -9108.0, ShipY: -7539.0, rot: 0
# PosX: -9095.0, PosY: -7570.0, rot: 0
# S 1
# ShipX: -9108.0, ShipY: -7539.0, rot: 0
# PosX: -9095.0, PosY: -7571.0, rot: 0
# W 3
# ShipX: -9108.0, ShipY: -7539.0, rot: 0
# PosX: -9098.0, PosY: -7571.0, rot: 0
# F 24
# ShipX: -8868.0, ShipY: -8307.0, rot: 0
# PosX: -8858.0, PosY: -8339.0, rot: 0
# L 90
# ShipX: -8868.0, ShipY: -8307.0, rot: 0
# PosX: -8836.0, PosY: -8297.0, rot: 0
# F 80
# ShipX: -6308.0, ShipY: -7507.0, rot: 0
# PosX: -6276.0, PosY: -7497.0, rot: 0
# S 2
# ShipX: -6308.0, ShipY: -7507.0, rot: 0
# PosX: -6276.0, PosY: -7499.0, rot: 0
# F 86
# ShipX: -3556.0, ShipY: -6819.0, rot: 0
# PosX: -3524.0, PosY: -6811.0, rot: 0
# F 7
# ShipX: -3332.0, ShipY: -6763.0, rot: 0
# PosX: -3300.0, PosY: -6755.0, rot: 0
# R 90
# ShipX: -3332.0, ShipY: -6763.0, rot: 0
# PosX: -3324.0, PosY: -6795.0, rot: 0
# E 1
# ShipX: -3332.0, ShipY: -6763.0, rot: 0
# PosX: -3323.0, PosY: -6795.0, rot: 0
# S 3
# ShipX: -3332.0, ShipY: -6763.0, rot: 0
# PosX: -3323.0, PosY: -6798.0, rot: 0
# W 3
# ShipX: -3332.0, ShipY: -6763.0, rot: 0
# PosX: -3326.0, PosY: -6798.0, rot: 0
# F 23
# ShipX: -3194.0, ShipY: -7568.0, rot: 0
# PosX: -3188.0, PosY: -7603.0, rot: 0
# R 90
# ShipX: -3194.0, ShipY: -7568.0, rot: 0
# PosX: -3229.0, PosY: -7574.0, rot: 0
# S 1
# ShipX: -3194.0, ShipY: -7568.0, rot: 0
# PosX: -3229.0, PosY: -7575.0, rot: 0
# W 4
# ShipX: -3194.0, ShipY: -7568.0, rot: 0
# PosX: -3233.0, PosY: -7575.0, rot: 0
# R 90
# ShipX: -3194.0, ShipY: -7568.0, rot: 0
# PosX: -3201.0, PosY: -7529.0, rot: 0
# N 4
# ShipX: -3194.0, ShipY: -7568.0, rot: 0
# PosX: -3201.0, PosY: -7525.0, rot: 0
# R 270
# ShipX: -3194.0, ShipY: -7568.0, rot: 0
# PosX: -3237.0, PosY: -7575.0, rot: 0
# S 1
# ShipX: -3194.0, ShipY: -7568.0, rot: 0
# PosX: -3237.0, PosY: -7576.0, rot: 0
# E 1
# ShipX: -3194.0, ShipY: -7568.0, rot: 0
# PosX: -3236.0, PosY: -7576.0, rot: 0
# F 20
# ShipX: -4034.0, ShipY: -7728.0, rot: 0
# PosX: -4076.0, PosY: -7736.0, rot: 0
# L 270
# ShipX: -4034.0, ShipY: -7728.0, rot: 0
# PosX: -4042.0, PosY: -7686.0, rot: 0
# F 31
# ShipX: -4282.0, ShipY: -6426.0, rot: 0
# PosX: -4290.0, PosY: -6384.0, rot: 0
# S 2
# ShipX: -4282.0, ShipY: -6426.0, rot: 0
# PosX: -4290.0, PosY: -6386.0, rot: 0
# L 180
# ShipX: -4282.0, ShipY: -6426.0, rot: 0
# PosX: -4274.0, PosY: -6466.0, rot: 0
# F 41
# ShipX: -3954.0, ShipY: -8066.0, rot: 0
# PosX: -3946.0, PosY: -8106.0, rot: 0
# E 3
# ShipX: -3954.0, ShipY: -8066.0, rot: 0
# PosX: -3943.0, PosY: -8106.0, rot: 0
# L 90
# ShipX: -3954.0, ShipY: -8066.0, rot: 0
# PosX: -3914.0, PosY: -8055.0, rot: 0
# N 3
# ShipX: -3954.0, ShipY: -8066.0, rot: 0
# PosX: -3914.0, PosY: -8052.0, rot: 0
# E 3
# ShipX: -3954.0, ShipY: -8066.0, rot: 0
# PosX: -3911.0, PosY: -8052.0, rot: 0
# N 1
# ShipX: -3954.0, ShipY: -8066.0, rot: 0
# PosX: -3911.0, PosY: -8051.0, rot: 0
# E 5
# ShipX: -3954.0, ShipY: -8066.0, rot: 0
# PosX: -3906.0, PosY: -8051.0, rot: 0
# F 27
# ShipX: -2658.0, ShipY: -7661.0, rot: 0
# PosX: -2610.0, PosY: -7646.0, rot: 0
# S 3
# ShipX: -2658.0, ShipY: -7661.0, rot: 0
# PosX: -2610.0, PosY: -7649.0, rot: 0
# W 2
# ShipX: -2658.0, ShipY: -7661.0, rot: 0
# PosX: -2612.0, PosY: -7649.0, rot: 0
# L 90
# ShipX: -2658.0, ShipY: -7661.0, rot: 0
# PosX: -2670.0, PosY: -7615.0, rot: 0
# E 5
# ShipX: -2658.0, ShipY: -7661.0, rot: 0
# PosX: -2665.0, PosY: -7615.0, rot: 0
# S 1
# ShipX: -2658.0, ShipY: -7661.0, rot: 0
# PosX: -2665.0, PosY: -7616.0, rot: 0
# F 9
# ShipX: -2721.0, ShipY: -7256.0, rot: 0
# PosX: -2728.0, PosY: -7211.0, rot: 0
# S 3
# ShipX: -2721.0, ShipY: -7256.0, rot: 0
# PosX: -2728.0, PosY: -7214.0, rot: 0
# E 2
# ShipX: -2721.0, ShipY: -7256.0, rot: 0
# PosX: -2726.0, PosY: -7214.0, rot: 0
# R 90
# ShipX: -2721.0, ShipY: -7256.0, rot: 0
# PosX: -2679.0, PosY: -7251.0, rot: 0
# S 5
# ShipX: -2721.0, ShipY: -7256.0, rot: 0
# PosX: -2679.0, PosY: -7256.0, rot: 0
# E 2
# ShipX: -2721.0, ShipY: -7256.0, rot: 0
# PosX: -2677.0, PosY: -7256.0, rot: 0
# R 180
# ShipX: -2721.0, ShipY: -7256.0, rot: 0
# PosX: -2765.0, PosY: -7256.0, rot: 0
# E 3
# ShipX: -2721.0, ShipY: -7256.0, rot: 0
# PosX: -2762.0, PosY: -7256.0, rot: 0
# F 32
# ShipX: -4033.0, ShipY: -7256.0, rot: 0
# PosX: -4074.0, PosY: -7256.0, rot: 0
# E 3
# ShipX: -4033.0, ShipY: -7256.0, rot: 0
# PosX: -4071.0, PosY: -7256.0, rot: 0
# S 1
# ShipX: -4033.0, ShipY: -7256.0, rot: 0
# PosX: -4071.0, PosY: -7257.0, rot: 0
# W 1
# ShipX: -4033.0, ShipY: -7256.0, rot: 0
# PosX: -4072.0, PosY: -7257.0, rot: 0
# F 39
# ShipX: -5554.0, ShipY: -7295.0, rot: 0
# PosX: -5593.0, PosY: -7296.0, rot: 0
# N 4
# ShipX: -5554.0, ShipY: -7295.0, rot: 0
# PosX: -5593.0, PosY: -7292.0, rot: 0
# F 5
# ShipX: -5749.0, ShipY: -7280.0, rot: 0
# PosX: -5788.0, PosY: -7277.0, rot: 0
# E 5
# ShipX: -5749.0, ShipY: -7280.0, rot: 0
# PosX: -5783.0, PosY: -7277.0, rot: 0
# F 26
# ShipX: -6633.0, ShipY: -7202.0, rot: 0
# PosX: -6667.0, PosY: -7199.0, rot: 0
# W 4
# ShipX: -6633.0, ShipY: -7202.0, rot: 0
# PosX: -6671.0, PosY: -7199.0, rot: 0
# S 1
# ShipX: -6633.0, ShipY: -7202.0, rot: 0
# PosX: -6671.0, PosY: -7200.0, rot: 0
# F 54
# ShipX: -8685.0, ShipY: -7094.0, rot: 0
# PosX: -8723.0, PosY: -7092.0, rot: 0
# S 5
# ShipX: -8685.0, ShipY: -7094.0, rot: 0
# PosX: -8723.0, PosY: -7097.0, rot: 0
# R 90
# ShipX: -8685.0, ShipY: -7094.0, rot: 0
# PosX: -8688.0, PosY: -7056.0, rot: 0
# F 50
# ShipX: -8835.0, ShipY: -5194.0, rot: 0
# PosX: -8838.0, PosY: -5156.0, rot: 0
# W 4
# ShipX: -8835.0, ShipY: -5194.0, rot: 0
# PosX: -8842.0, PosY: -5156.0, rot: 0
# S 1
# ShipX: -8835.0, ShipY: -5194.0, rot: 0
# PosX: -8842.0, PosY: -5157.0, rot: 0
# L 90
# ShipX: -8835.0, ShipY: -5194.0, rot: 0
# PosX: -8872.0, PosY: -5201.0, rot: 0
# S 5
# ShipX: -8835.0, ShipY: -5194.0, rot: 0
# PosX: -8872.0, PosY: -5206.0, rot: 0
# L 90
# ShipX: -8835.0, ShipY: -5194.0, rot: 0
# PosX: -8823.0, PosY: -5231.0, rot: 0
# F 2
# ShipX: -8811.0, ShipY: -5268.0, rot: 0
# PosX: -8799.0, PosY: -5305.0, rot: 0
# E 5
# ShipX: -8811.0, ShipY: -5268.0, rot: 0
# PosX: -8794.0, PosY: -5305.0, rot: 0
# L 90
# ShipX: -8811.0, ShipY: -5268.0, rot: 0
# PosX: -8774.0, PosY: -5251.0, rot: 0
# N 1
# ShipX: -8811.0, ShipY: -5268.0, rot: 0
# PosX: -8774.0, PosY: -5250.0, rot: 0
# W 3
# ShipX: -8811.0, ShipY: -5268.0, rot: 0
# PosX: -8777.0, PosY: -5250.0, rot: 0
# F 75
# ShipX: -6261.0, ShipY: -3918.0, rot: 0
# PosX: -6227.0, PosY: -3900.0, rot: 0
# L 90
# ShipX: -6261.0, ShipY: -3918.0, rot: 0
# PosX: -6279.0, PosY: -3884.0, rot: 0
# F 85
# ShipX: -7791.0, ShipY: -1028.0, rot: 0
# PosX: -7809.0, PosY: -994.0, rot: 0
# S 2
# ShipX: -7791.0, ShipY: -1028.0, rot: 0
# PosX: -7809.0, PosY: -996.0, rot: 0
# W 4
# ShipX: -7791.0, ShipY: -1028.0, rot: 0
# PosX: -7813.0, PosY: -996.0, rot: 0
# F 93
# ShipX: -9837.0, ShipY: 1948.0, rot: 0
# PosX: -9859.0, PosY: 1980.0, rot: 0
# S 4
# ShipX: -9837.0, ShipY: 1948.0, rot: 0
# PosX: -9859.0, PosY: 1976.0, rot: 0
# E 3
# ShipX: -9837.0, ShipY: 1948.0, rot: 0
# PosX: -9856.0, PosY: 1976.0, rot: 0
# S 2
# ShipX: -9837.0, ShipY: 1948.0, rot: 0
# PosX: -9856.0, PosY: 1974.0, rot: 0
# E 4
# ShipX: -9837.0, ShipY: 1948.0, rot: 0
# PosX: -9852.0, PosY: 1974.0, rot: 0
# R 90
# ShipX: -9837.0, ShipY: 1948.0, rot: 0
# PosX: -9811.0, PosY: 1963.0, rot: 0
# S 3
# ShipX: -9837.0, ShipY: 1948.0, rot: 0
# PosX: -9811.0, PosY: 1960.0, rot: 0
# W 1
# ShipX: -9837.0, ShipY: 1948.0, rot: 0
# PosX: -9812.0, PosY: 1960.0, rot: 0
# F 94
# ShipX: -7487.0, ShipY: 3076.0, rot: 0
# PosX: -7462.0, PosY: 3088.0, rot: 0
# R 90
# ShipX: -7487.0, ShipY: 3076.0, rot: 0
# PosX: -7475.0, PosY: 3051.0, rot: 0
# N 3
# ShipX: -7487.0, ShipY: 3076.0, rot: 0
# PosX: -7475.0, PosY: 3054.0, rot: 0
# R 270
# ShipX: -7487.0, ShipY: 3076.0, rot: 0
# PosX: -7465.0, PosY: 3088.0, rot: 0
# S 2
# ShipX: -7487.0, ShipY: 3076.0, rot: 0
# PosX: -7465.0, PosY: 3086.0, rot: 0
# W 3
# ShipX: -7487.0, ShipY: 3076.0, rot: 0
# PosX: -7468.0, PosY: 3086.0, rot: 0
# N 5
# ShipX: -7487.0, ShipY: 3076.0, rot: 0
# PosX: -7468.0, PosY: 3091.0, rot: 0
# F 1
# ShipX: -7468.0, ShipY: 3091.0, rot: 0
# PosX: -7449.0, PosY: 3106.0, rot: 0
# S 1
# ShipX: -7468.0, ShipY: 3091.0, rot: 0
# PosX: -7449.0, PosY: 3105.0, rot: 0
# F 32
# ShipX: -6860.0, ShipY: 3539.0, rot: 0
# PosX: -6841.0, PosY: 3553.0, rot: 0
# E 2
# ShipX: -6860.0, ShipY: 3539.0, rot: 0
# PosX: -6839.0, PosY: 3553.0, rot: 0
# F 17
# ShipX: -6503.0, ShipY: 3777.0, rot: 0
# PosX: -6482.0, PosY: 3791.0, rot: 0
# N 4
# ShipX: -6503.0, ShipY: 3777.0, rot: 0
# PosX: -6482.0, PosY: 3795.0, rot: 0
# W 2
# ShipX: -6503.0, ShipY: 3777.0, rot: 0
# PosX: -6484.0, PosY: 3795.0, rot: 0
# S 4
# ShipX: -6503.0, ShipY: 3777.0, rot: 0
# PosX: -6484.0, PosY: 3791.0, rot: 0
# L 90
# ShipX: -6503.0, ShipY: 3777.0, rot: 0
# PosX: -6517.0, PosY: 3796.0, rot: 0
# W 2
# ShipX: -6503.0, ShipY: 3777.0, rot: 0
# PosX: -6519.0, PosY: 3796.0, rot: 0
# N 2
# ShipX: -6503.0, ShipY: 3777.0, rot: 0
# PosX: -6519.0, PosY: 3798.0, rot: 0
# L 180
# ShipX: -6503.0, ShipY: 3777.0, rot: 0
# PosX: -6487.0, PosY: 3756.0, rot: 0
# F 94
# ShipX: -4999.0, ShipY: 1803.0, rot: 0
# PosX: -4983.0, PosY: 1782.0, rot: 0
# R 90
# ShipX: -4999.0, ShipY: 1803.0, rot: 0
# PosX: -5020.0, PosY: 1787.0, rot: 0
# F 78
# ShipX: -6637.0, ShipY: 555.0, rot: 0
# PosX: -6658.0, PosY: 539.0, rot: 0
# N 3
# ShipX: -6637.0, ShipY: 555.0, rot: 0
# PosX: -6658.0, PosY: 542.0, rot: 0
# E 3
# ShipX: -6637.0, ShipY: 555.0, rot: 0
# PosX: -6655.0, PosY: 542.0, rot: 0
# N 3
# ShipX: -6637.0, ShipY: 555.0, rot: 0
# PosX: -6655.0, PosY: 545.0, rot: 0
# E 4
# ShipX: -6637.0, ShipY: 555.0, rot: 0
# PosX: -6651.0, PosY: 545.0, rot: 0
# F 37
# ShipX: -7155.0, ShipY: 185.0, rot: 0
# PosX: -7169.0, PosY: 175.0, rot: 0
# E 5
# ShipX: -7155.0, ShipY: 185.0, rot: 0
# PosX: -7164.0, PosY: 175.0, rot: 0
# L 180
# ShipX: -7155.0, ShipY: 185.0, rot: 0
# PosX: -7146.0, PosY: 195.0, rot: 0
# W 2
# ShipX: -7155.0, ShipY: 185.0, rot: 0
# PosX: -7148.0, PosY: 195.0, rot: 0
# L 180
# ShipX: -7155.0, ShipY: 185.0, rot: 0
# PosX: -7162.0, PosY: 175.0, rot: 0
# N 2
# ShipX: -7155.0, ShipY: 185.0, rot: 0
# PosX: -7162.0, PosY: 177.0, rot: 0
# R 270
# ShipX: -7155.0, ShipY: 185.0, rot: 0
# PosX: -7147.0, PosY: 178.0, rot: 0
# S 2
# ShipX: -7155.0, ShipY: 185.0, rot: 0
# PosX: -7147.0, PosY: 176.0, rot: 0
# F 28
# ShipX: -6931.0, ShipY: -67.0, rot: 0
# PosX: -6923.0, PosY: -76.0, rot: 0
# R 90
# ShipX: -6931.0, ShipY: -67.0, rot: 0
# PosX: -6940.0, PosY: -75.0, rot: 0
# S 1
# ShipX: -6931.0, ShipY: -67.0, rot: 0
# PosX: -6940.0, PosY: -76.0, rot: 0
# F 15
# ShipX: -7066.0, ShipY: -202.0, rot: 0
# PosX: -7075.0, PosY: -211.0, rot: 0
# E 1
# ShipX: -7066.0, ShipY: -202.0, rot: 0
# PosX: -7074.0, PosY: -211.0, rot: 0
# F 50
# ShipX: -7466.0, ShipY: -652.0, rot: 0
# PosX: -7474.0, PosY: -661.0, rot: 0
# N 3
# ShipX: -7466.0, ShipY: -652.0, rot: 0
# PosX: -7474.0, PosY: -658.0, rot: 0
# R 90
# ShipX: -7466.0, ShipY: -652.0, rot: 0
# PosX: -7472.0, PosY: -644.0, rot: 0
# F 14
# ShipX: -7550.0, ShipY: -540.0, rot: 0
# PosX: -7556.0, PosY: -532.0, rot: 0
# N 4
# ShipX: -7550.0, ShipY: -540.0, rot: 0
# PosX: -7556.0, PosY: -528.0, rot: 0
# F 80
# ShipX: -8030.0, ShipY: 420.0, rot: 0
# PosX: -8036.0, PosY: 432.0, rot: 0
# L 90
# ShipX: -8030.0, ShipY: 420.0, rot: 0
# PosX: -8042.0, PosY: 414.0, rot: 0
# S 5
# ShipX: -8030.0, ShipY: 420.0, rot: 0
# PosX: -8042.0, PosY: 409.0, rot: 0
# W 1
# ShipX: -8030.0, ShipY: 420.0, rot: 0
# PosX: -8043.0, PosY: 409.0, rot: 0
# L 90
# ShipX: -8030.0, ShipY: 420.0, rot: 0
# PosX: -8019.0, PosY: 407.0, rot: 0
# W 5
# ShipX: -8030.0, ShipY: 420.0, rot: 0
# PosX: -8024.0, PosY: 407.0, rot: 0
# F 100
# ShipX: -7430.0, ShipY: -880.0, rot: 0
# PosX: -7424.0, PosY: -893.0, rot: 0
# N 1
# ShipX: -7430.0, ShipY: -880.0, rot: 0
# PosX: -7424.0, PosY: -892.0, rot: 0
# L 90
# ShipX: -7430.0, ShipY: -880.0, rot: 0
# PosX: -7418.0, PosY: -874.0, rot: 0
# N 5
# ShipX: -7430.0, ShipY: -880.0, rot: 0
# PosX: -7418.0, PosY: -869.0, rot: 0
# W 2
# ShipX: -7430.0, ShipY: -880.0, rot: 0
# PosX: -7420.0, PosY: -869.0, rot: 0
# N 1
# ShipX: -7430.0, ShipY: -880.0, rot: 0
# PosX: -7420.0, PosY: -868.0, rot: 0
# F 76
# ShipX: -6670.0, ShipY: 32.0, rot: 0
# PosX: -6660.0, PosY: 44.0, rot: 0
# L 180
# ShipX: -6670.0, ShipY: 32.0, rot: 0
# PosX: -6680.0, PosY: 20.0, rot: 0
# S 3
# ShipX: -6670.0, ShipY: 32.0, rot: 0
# PosX: -6680.0, PosY: 17.0, rot: 0
# L 180
# ShipX: -6670.0, ShipY: 32.0, rot: 0
# PosX: -6660.0, PosY: 47.0, rot: 0
# E 1
# ShipX: -6670.0, ShipY: 32.0, rot: 0
# PosX: -6659.0, PosY: 47.0, rot: 0
# E 5
# ShipX: -6670.0, ShipY: 32.0, rot: 0
# PosX: -6654.0, PosY: 47.0, rot: 0
# F 1
# ShipX: -6654.0, ShipY: 47.0, rot: 0
# PosX: -6638.0, PosY: 62.0, rot: 0
# R 90
# ShipX: -6654.0, ShipY: 47.0, rot: 0
# PosX: -6639.0, PosY: 30.999999999999996, rot: 0
# W 4
# ShipX: -6654.0, ShipY: 47.0, rot: 0
# PosX: -6643.0, PosY: 30.999999999999996, rot: 0
# F 95
# ShipX: -5609.0, ShipY: -1473.0, rot: 0
# PosX: -5598.0, PosY: -1489.0, rot: 0
# S 2
# ShipX: -5609.0, ShipY: -1473.0, rot: 0
# PosX: -5598.0, PosY: -1491.0, rot: 0
# R 90
# ShipX: -5609.0, ShipY: -1473.0, rot: 0
# PosX: -5627.0, PosY: -1484.0, rot: 0
# W 2
# ShipX: -5609.0, ShipY: -1473.0, rot: 0
# PosX: -5629.0, PosY: -1484.0, rot: 0
# F 29
# ShipX: -6189.0, ShipY: -1792.0, rot: 0
# PosX: -6209.0, PosY: -1803.0, rot: 0
# W 2
# ShipX: -6189.0, ShipY: -1792.0, rot: 0
# PosX: -6211.0, PosY: -1803.0, rot: 0
# F 47
# ShipX: -7223.0, ShipY: -2309.0, rot: 0
# PosX: -7245.0, PosY: -2320.0, rot: 0
# W 5
# ShipX: -7223.0, ShipY: -2309.0, rot: 0
# PosX: -7250.0, PosY: -2320.0, rot: 0
# S 5
# ShipX: -7223.0, ShipY: -2309.0, rot: 0
# PosX: -7250.0, PosY: -2325.0, rot: 0
# W 4
# ShipX: -7223.0, ShipY: -2309.0, rot: 0
# PosX: -7254.0, PosY: -2325.0, rot: 0
# F 58
# ShipX: -9021.0, ShipY: -3237.0, rot: 0
# PosX: -9052.0, PosY: -3253.0, rot: 0
# L 90
# ShipX: -9021.0, ShipY: -3237.0, rot: 0
# PosX: -9005.0, PosY: -3268.0, rot: 0
# F 22
# ShipX: -8669.0, ShipY: -3919.0, rot: 0
# PosX: -8653.0, PosY: -3950.0, rot: 0
# N 1
# ShipX: -8669.0, ShipY: -3919.0, rot: 0
# PosX: -8653.0, PosY: -3949.0, rot: 0
# E 4
# ShipX: -8669.0, ShipY: -3919.0, rot: 0
# PosX: -8649.0, PosY: -3949.0, rot: 0
# N 4
# ShipX: -8669.0, ShipY: -3919.0, rot: 0
# PosX: -8649.0, PosY: -3945.0, rot: 0
# E 2
# ShipX: -8669.0, ShipY: -3919.0, rot: 0
# PosX: -8647.0, PosY: -3945.0, rot: 0
# S 5
# ShipX: -8669.0, ShipY: -3919.0, rot: 0
# PosX: -8647.0, PosY: -3950.0, rot: 0
# L 180
# ShipX: -8669.0, ShipY: -3919.0, rot: 0
# PosX: -8691.0, PosY: -3888.0, rot: 0
# W 4
# ShipX: -8669.0, ShipY: -3919.0, rot: 0
# PosX: -8695.0, PosY: -3888.0, rot: 0
# N 2
# ShipX: -8669.0, ShipY: -3919.0, rot: 0
# PosX: -8695.0, PosY: -3886.0, rot: 0
# W 3
# ShipX: -8669.0, ShipY: -3919.0, rot: 0
# PosX: -8698.0, PosY: -3886.0, rot: 0
# R 90
# ShipX: -8669.0, ShipY: -3919.0, rot: 0
# PosX: -8636.0, PosY: -3890.0, rot: 0
# F 76
# ShipX: -6161.0, ShipY: -1715.0, rot: 0
# PosX: -6128.0, PosY: -1686.0, rot: 0
# N 1
# ShipX: -6161.0, ShipY: -1715.0, rot: 0
# PosX: -6128.0, PosY: -1685.0, rot: 0
# F 41
# ShipX: -4808.0, ShipY: -485.0, rot: 0
# PosX: -4775.0, PosY: -455.0, rot: 0
# W 5
# ShipX: -4808.0, ShipY: -485.0, rot: 0
# PosX: -4780.0, PosY: -455.0, rot: 0
# F 48
# ShipX: -3464.0, ShipY: 955.0, rot: 0
# PosX: -3436.0, PosY: 985.0, rot: 0
# W 1
# ShipX: -3464.0, ShipY: 955.0, rot: 0
# PosX: -3437.0, PosY: 985.0, rot: 0
# N 4
# ShipX: -3464.0, ShipY: 955.0, rot: 0
# PosX: -3437.0, PosY: 989.0, rot: 0
# E 2
# ShipX: -3464.0, ShipY: 955.0, rot: 0
# PosX: -3435.0, PosY: 989.0, rot: 0
# R 180
# ShipX: -3464.0, ShipY: 955.0, rot: 0
# PosX: -3493.0, PosY: 921.0, rot: 0
# F 79
# ShipX: -5755.0, ShipY: -1731.0, rot: 0
# PosX: -5784.0, PosY: -1765.0, rot: 0
# N 1
# ShipX: -5755.0, ShipY: -1731.0, rot: 0
# PosX: -5784.0, PosY: -1764.0, rot: 0
# L 90
# ShipX: -5755.0, ShipY: -1731.0, rot: 0
# PosX: -5722.0, PosY: -1760.0, rot: 0
# S 4
# ShipX: -5755.0, ShipY: -1731.0, rot: 0
# PosX: -5722.0, PosY: -1764.0, rot: 0
# E 2
# ShipX: -5755.0, ShipY: -1731.0, rot: 0
# PosX: -5720.0, PosY: -1764.0, rot: 0
# F 86
# ShipX: -2745.0, ShipY: -4569.0, rot: 0
# PosX: -2710.0, PosY: -4602.0, rot: 0
# N 2
# ShipX: -2745.0, ShipY: -4569.0, rot: 0
# PosX: -2710.0, PosY: -4600.0, rot: 0
# E 1
# ShipX: -2745.0, ShipY: -4569.0, rot: 0
# PosX: -2709.0, PosY: -4600.0, rot: 0
# F 5
# ShipX: -2565.0, ShipY: -4724.0, rot: 0
# PosX: -2529.0, PosY: -4755.0, rot: 0
# W 4
# ShipX: -2565.0, ShipY: -4724.0, rot: 0
# PosX: -2533.0, PosY: -4755.0, rot: 0
# S 2
# ShipX: -2565.0, ShipY: -4724.0, rot: 0
# PosX: -2533.0, PosY: -4757.0, rot: 0
# L 90
# ShipX: -2565.0, ShipY: -4724.0, rot: 0
# PosX: -2532.0, PosY: -4692.0, rot: 0
# F 3
# ShipX: -2466.0, ShipY: -4628.0, rot: 0
# PosX: -2433.0, PosY: -4596.0, rot: 0
# R 270
# ShipX: -2466.0, ShipY: -4628.0, rot: 0
# PosX: -2498.0, PosY: -4595.0, rot: 0
# F 43
# ShipX: -3842.0, ShipY: -3209.0, rot: 0
# PosX: -3874.0, PosY: -3176.0, rot: 0
# L 180
# ShipX: -3842.0, ShipY: -3209.0, rot: 0
# PosX: -3810.0, PosY: -3242.0, rot: 0
# S 5
# ShipX: -3842.0, ShipY: -3209.0, rot: 0
# PosX: -3810.0, PosY: -3247.0, rot: 0
# R 90
# ShipX: -3842.0, ShipY: -3209.0, rot: 0
# PosX: -3880.0, PosY: -3241.0, rot: 0
# W 5
# ShipX: -3842.0, ShipY: -3209.0, rot: 0
# PosX: -3885.0, PosY: -3241.0, rot: 0
# R 180
# ShipX: -3842.0, ShipY: -3209.0, rot: 0
# PosX: -3799.0, PosY: -3177.0, rot: 0
# E 4
# ShipX: -3842.0, ShipY: -3209.0, rot: 0
# PosX: -3795.0, PosY: -3177.0, rot: 0
# S 3
# ShipX: -3842.0, ShipY: -3209.0, rot: 0
# PosX: -3795.0, PosY: -3180.0, rot: 0
# R 90
# ShipX: -3842.0, ShipY: -3209.0, rot: 0
# PosX: -3813.0, PosY: -3256.0, rot: 0
# S 2
# ShipX: -3842.0, ShipY: -3209.0, rot: 0
# PosX: -3813.0, PosY: -3258.0, rot: 0
# F 41
# ShipX: -2653.0, ShipY: -5218.0, rot: 0
# PosX: -2624.0, PosY: -5267.0, rot: 0
# F 70
# ShipX: -623.0, ShipY: -8648.0, rot: 0
# PosX: -594.0, PosY: -8697.0, rot: 0
# L 270
# ShipX: -623.0, ShipY: -8648.0, rot: 0
# PosX: -672.0, PosY: -8677.0, rot: 0
# E 4
# ShipX: -623.0, ShipY: -8648.0, rot: 0
# PosX: -668.0, PosY: -8677.0, rot: 0
# R 90
# ShipX: -623.0, ShipY: -8648.0, rot: 0
# PosX: -652.0, PosY: -8603.0, rot: 0
# F 18
# ShipX: -1145.0, ShipY: -7838.0, rot: 0
# PosX: -1174.0, PosY: -7793.0, rot: 0
# S 4
# ShipX: -1145.0, ShipY: -7838.0, rot: 0
# PosX: -1174.0, PosY: -7797.0, rot: 0
# F 88
# ShipX: -3697.0, ShipY: -4230.0, rot: 0
# PosX: -3726.0, PosY: -4189.0, rot: 0
# E 2
# ShipX: -3697.0, ShipY: -4230.0, rot: 0
# PosX: -3724.0, PosY: -4189.0, rot: 0
# L 90
# ShipX: -3697.0, ShipY: -4230.0, rot: 0
# PosX: -3738.0, PosY: -4257.0, rot: 0
# L 270
# ShipX: -3697.0, ShipY: -4230.0, rot: 0
# PosX: -3724.0, PosY: -4189.0, rot: 0
# F 56
# ShipX: -5209.0, ShipY: -1934.0, rot: 0
# PosX: -5236.0, PosY: -1893.0, rot: 0
# L 90
# ShipX: -5209.0, ShipY: -1934.0, rot: 0
# PosX: -5250.0, PosY: -1961.0, rot: 0
# N 1
# ShipX: -5209.0, ShipY: -1934.0, rot: 0
# PosX: -5250.0, PosY: -1960.0, rot: 0
# L 90
# ShipX: -5209.0, ShipY: -1934.0, rot: 0
# PosX: -5183.0, PosY: -1975.0, rot: 0
# F 7
# ShipX: -5027.0, ShipY: -2221.0, rot: 0
# PosX: -5001.0, PosY: -2262.0, rot: 0
# S 3
# ShipX: -5027.0, ShipY: -2221.0, rot: 0
# PosX: -5001.0, PosY: -2265.0, rot: 0
# F 36
# ShipX: -4091.0, ShipY: -3805.0, rot: 0
# PosX: -4065.0, PosY: -3849.0, rot: 0
# L 90
# ShipX: -4091.0, ShipY: -3805.0, rot: 0
# PosX: -4047.0, PosY: -3779.0, rot: 0
# F 2
# ShipX: -4003.0, ShipY: -3753.0, rot: 0
# PosX: -3959.0, PosY: -3727.0, rot: 0
# L 90
# ShipX: -4003.0, ShipY: -3753.0, rot: 0
# PosX: -4029.0, PosY: -3709.0, rot: 0
# F 2
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4081.0, PosY: -3621.0, rot: 0
# W 4
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4085.0, PosY: -3621.0, rot: 0
# S 4
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4085.0, PosY: -3625.0, rot: 0
# L 90
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4095.0, PosY: -3695.0, rot: 0
# E 5
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4090.0, PosY: -3695.0, rot: 0
# N 2
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4090.0, PosY: -3693.0, rot: 0
# L 90
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4027.0, PosY: -3700.0, rot: 0
# S 4
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4027.0, PosY: -3704.0, rot: 0
# R 90
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4094.0, PosY: -3693.0, rot: 0
# W 1
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4095.0, PosY: -3693.0, rot: 0
# R 90
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4083.0, PosY: -3625.0, rot: 0
# N 2
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4083.0, PosY: -3623.0, rot: 0
# E 3
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4080.0, PosY: -3623.0, rot: 0
# W 2
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4082.0, PosY: -3623.0, rot: 0
# S 4
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4082.0, PosY: -3627.0, rot: 0
# E 4
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4078.0, PosY: -3627.0, rot: 0
# R 90
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4017.0, PosY: -3642.0, rot: 0
# N 5
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4017.0, PosY: -3637.0, rot: 0
# L 90
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4083.0, PosY: -3627.0, rot: 0
# N 4
# ShipX: -4055.0, ShipY: -3665.0, rot: 0
# PosX: -4083.0, PosY: -3623.0, rot: 0
# F 55
# ShipX: -5595.0, ShipY: -1355.0, rot: 0
# PosX: -5623.0, PosY: -1313.0, rot: 0
# N 3
# ShipX: -5595.0, ShipY: -1355.0, rot: 0
# PosX: -5623.0, PosY: -1310.0, rot: 0
# E 1
# ShipX: -5595.0, ShipY: -1355.0, rot: 0
# PosX: -5622.0, PosY: -1310.0, rot: 0
# F 80
# ShipX: -7755.0, ShipY: 2245.0, rot: 0
# PosX: -7782.0, PosY: 2290.0, rot: 0
# W 2
# ShipX: -7755.0, ShipY: 2245.0, rot: 0
# PosX: -7784.0, PosY: 2290.0, rot: 0
# R 90
# ShipX: -7755.0, ShipY: 2245.0, rot: 0
# PosX: -7710.0, PosY: 2274.0, rot: 0
# S 2
# ShipX: -7755.0, ShipY: 2245.0, rot: 0
# PosX: -7710.0, PosY: 2272.0, rot: 0
# L 90
# ShipX: -7755.0, ShipY: 2245.0, rot: 0
# PosX: -7782.0, PosY: 2290.0, rot: 0
# W 5
# ShipX: -7755.0, ShipY: 2245.0, rot: 0
# PosX: -7787.0, PosY: 2290.0, rot: 0
# R 90
# ShipX: -7755.0, ShipY: 2245.0, rot: 0
# PosX: -7710.0, PosY: 2277.0, rot: 0
# R 90
# ShipX: -7755.0, ShipY: 2245.0, rot: 0
# PosX: -7723.0, PosY: 2200.0, rot: 0
# F 87
# ShipX: -4971.0, ShipY: -1670.0, rot: 0
# PosX: -4939.0, PosY: -1715.0, rot: 0
# L 270
# ShipX: -4971.0, ShipY: -1670.0, rot: 0
# PosX: -5016.0, PosY: -1702.0, rot: 0
# S 5
# ShipX: -4971.0, ShipY: -1670.0, rot: 0
# PosX: -5016.0, PosY: -1707.0, rot: 0
# R 270
# ShipX: -4971.0, ShipY: -1670.0, rot: 0
# PosX: -4934.0, PosY: -1715.0, rot: 0
# N 5
# ShipX: -4971.0, ShipY: -1670.0, rot: 0
# PosX: -4934.0, PosY: -1710.0, rot: 0
# E 5
# ShipX: -4971.0, ShipY: -1670.0, rot: 0
# PosX: -4929.0, PosY: -1710.0, rot: 0
# F 10
# ShipX: -4551.0, ShipY: -2070.0, rot: 0
# PosX: -4509.0, PosY: -2110.0, rot: 0
# E 1
# ShipX: -4551.0, ShipY: -2070.0, rot: 0
# PosX: -4508.0, PosY: -2110.0, rot: 0
# R 180
# ShipX: -4551.0, ShipY: -2070.0, rot: 0
# PosX: -4594.0, PosY: -2030.0, rot: 0
# N 1
# ShipX: -4551.0, ShipY: -2070.0, rot: 0
# PosX: -4594.0, PosY: -2029.0, rot: 0
# L 90
# ShipX: -4551.0, ShipY: -2070.0, rot: 0
# PosX: -4592.0, PosY: -2113.0, rot: 0
# S 3
# ShipX: -4551.0, ShipY: -2070.0, rot: 0
# PosX: -4592.0, PosY: -2116.0, rot: 0
# W 1
# ShipX: -4551.0, ShipY: -2070.0, rot: 0
# PosX: -4593.0, PosY: -2116.0, rot: 0
# F 18
# ShipX: -5307.0, ShipY: -2898.0, rot: 0
# PosX: -5349.0, PosY: -2944.0, rot: 0
# R 90
# ShipX: -5307.0, ShipY: -2898.0, rot: 0
# PosX: -5353.0, PosY: -2856.0, rot: 0
# S 3
# ShipX: -5307.0, ShipY: -2898.0, rot: 0
# PosX: -5353.0, PosY: -2859.0, rot: 0
# F 89
# ShipX: -9401.0, ShipY: 573.0, rot: 0
# PosX: -9447.0, PosY: 612.0, rot: 0
# L 90
# ShipX: -9401.0, ShipY: 573.0, rot: 0
# PosX: -9440.0, PosY: 527.0, rot: 0
# F 42
# ShipX: -11039.0, ShipY: -1359.0, rot: 0
# PosX: -11078.0, PosY: -1405.0, rot: 0
# S 3
# ShipX: -11039.0, ShipY: -1359.0, rot: 0
# PosX: -11078.0, PosY: -1408.0, rot: 0
# R 180
# ShipX: -11039.0, ShipY: -1359.0, rot: 0
# PosX: -11000.0, PosY: -1310.0, rot: 0
# F 92
# ShipX: -7451.0, ShipY: 3149.0, rot: 0
# PosX: -7412.0, PosY: 3198.0, rot: 0
# L 90
# ShipX: -7451.0, ShipY: 3149.0, rot: 0
# PosX: -7500.0, PosY: 3188.0, rot: 0
# F 48
# ShipX: -9803.0, ShipY: 5021.0, rot: 0
# PosX: -9852.0, PosY: 5060.0, rot: 0
# F 11
# ShipX: -10342.0, ShipY: 5450.0, rot: 0
# PosX: -10391.0, PosY: 5489.0, rot: 0
# W 2
# ShipX: -10342.0, ShipY: 5450.0, rot: 0
# PosX: -10393.0, PosY: 5489.0, rot: 0
# L 180
# ShipX: -10342.0, ShipY: 5450.0, rot: 0
# PosX: -10291.0, PosY: 5411.0, rot: 0
# F 27
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -8914.0, PosY: 4358.0, rot: 0
# L 180
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -9016.0, PosY: 4436.0, rot: 0
# N 3
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -9016.0, PosY: 4439.0, rot: 0
# W 1
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -9017.0, PosY: 4439.0, rot: 0
# S 2
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -9017.0, PosY: 4437.0, rot: 0
# L 90
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -9005.0, PosY: 4345.0, rot: 0
# W 1
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -9006.0, PosY: 4345.0, rot: 0
# N 1
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -9006.0, PosY: 4346.0, rot: 0
# W 4
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -9010.0, PosY: 4346.0, rot: 0
# N 1
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -9010.0, PosY: 4347.0, rot: 0
# R 90
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -9015.0, PosY: 4442.0, rot: 0
# S 2
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -9015.0, PosY: 4440.0, rot: 0
# W 5
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -9020.0, PosY: 4440.0, rot: 0
# E 1
# ShipX: -8965.0, ShipY: 4397.0, rot: 0
# PosX: -9019.0, PosY: 4440.0, rot: 0
# F 74
# ShipX: -12961.0, ShipY: 7579.0, rot: 0
# PosX: -13015.0, PosY: 7622.0, rot: 0
# L 180
# ShipX: -12961.0, ShipY: 7579.0, rot: 0
# PosX: -12907.0, PosY: 7536.0, rot: 0
# F 48
# ShipX: -10369.0, ShipY: 5515.0, rot: 0
# PosX: -10315.0, PosY: 5472.0, rot: 0
# W 3
# ShipX: -10369.0, ShipY: 5515.0, rot: 0
# PosX: -10318.0, PosY: 5472.0, rot: 0
# F 3
# ShipX: -10216.0, ShipY: 5386.0, rot: 0
# PosX: -10165.0, PosY: 5343.0, rot: 0
# E 3
# ShipX: -10216.0, ShipY: 5386.0, rot: 0
# PosX: -10162.0, PosY: 5343.0, rot: 0
# F 74
# ShipX: -6220.0, ShipY: 2204.0, rot: 0
# PosX: -6166.0, PosY: 2161.0, rot: 0
# L 270
# ShipX: -6220.0, ShipY: 2204.0, rot: 0
# PosX: -6263.0, PosY: 2150.0, rot: 0
# F 38
# ShipX: -7854.0, ShipY: 152.0, rot: 0
# PosX: -7897.0, PosY: 98.0, rot: 0
# R 180
# ShipX: -7854.0, ShipY: 152.0, rot: 0
# PosX: -7811.0, PosY: 206.0, rot: 0
# N 2
# ShipX: -7854.0, ShipY: 152.0, rot: 0
# PosX: -7811.0, PosY: 208.0, rot: 0
# F 83
# ShipX: -4285.0, ShipY: 4800.0, rot: 0
# PosX: -4242.0, PosY: 4856.0, rot: 0
# S 1
# ShipX: -4285.0, ShipY: 4800.0, rot: 0
# PosX: -4242.0, PosY: 4855.0, rot: 0
# F 78
# ShipX: -931.0, ShipY: 9090.0, rot: 0
# PosX: -888.0, PosY: 9145.0, rot: 0
# L 90
# ShipX: -931.0, ShipY: 9090.0, rot: 0
# PosX: -986.0, PosY: 9133.0, rot: 0
# N 4
# ShipX: -931.0, ShipY: 9090.0, rot: 0
# PosX: -986.0, PosY: 9137.0, rot: 0
# F 43
# ShipX: -3296.0, ShipY: 11111.0, rot: 0
# PosX: -3351.0, PosY: 11158.0, rot: 0
# W 3
# ShipX: -3296.0, ShipY: 11111.0, rot: 0
# PosX: -3354.0, PosY: 11158.0, rot: 0
# W 2
# ShipX: -3296.0, ShipY: 11111.0, rot: 0
# PosX: -3356.0, PosY: 11158.0, rot: 0
# N 1
# ShipX: -3296.0, ShipY: 11111.0, rot: 0
# PosX: -3356.0, PosY: 11159.0, rot: 0
# L 90
# ShipX: -3296.0, ShipY: 11111.0, rot: 0
# PosX: -3344.0, PosY: 11051.0, rot: 0
# N 2
# ShipX: -3296.0, ShipY: 11111.0, rot: 0
# PosX: -3344.0, PosY: 11053.0, rot: 0
# W 4
# ShipX: -3296.0, ShipY: 11111.0, rot: 0
# PosX: -3348.0, PosY: 11053.0, rot: 0
# L 90
# ShipX: -3296.0, ShipY: 11111.0, rot: 0
# PosX: -3238.0, PosY: 11059.0, rot: 0
# S 5
# ShipX: -3296.0, ShipY: 11111.0, rot: 0
# PosX: -3238.0, PosY: 11054.0, rot: 0
# E 5
# ShipX: -3296.0, ShipY: 11111.0, rot: 0
# PosX: -3233.0, PosY: 11054.0, rot: 0
# W 1
# ShipX: -3296.0, ShipY: 11111.0, rot: 0
# PosX: -3234.0, PosY: 11054.0, rot: 0
# F 83
# ShipX: 1850.0, ShipY: 6380.0, rot: 0
# PosX: 1912.0, PosY: 6323.0, rot: 0
# E 5
# ShipX: 1850.0, ShipY: 6380.0, rot: 0
# PosX: 1917.0, PosY: 6323.0, rot: 0
# F 70
# ShipX: 6540.0, ShipY: 2390.0, rot: 0
# PosX: 6607.0, PosY: 2333.0, rot: 0
# N 2
# ShipX: 6540.0, ShipY: 2390.0, rot: 0
# PosX: 6607.0, PosY: 2335.0, rot: 0
# L 90
# ShipX: 6540.0, ShipY: 2390.0, rot: 0
# PosX: 6595.0, PosY: 2457.0, rot: 0
# N 2
# ShipX: 6540.0, ShipY: 2390.0, rot: 0
# PosX: 6595.0, PosY: 2459.0, rot: 0
# F 66
# ShipX: 10170.0, ShipY: 6944.0, rot: 0
# PosX: 10225.0, PosY: 7013.0, rot: 0
# S 2
# ShipX: 10170.0, ShipY: 6944.0, rot: 0
# PosX: 10225.0, PosY: 7011.0, rot: 0
# E 2
# ShipX: 10170.0, ShipY: 6944.0, rot: 0
# PosX: 10227.0, PosY: 7011.0, rot: 0
# R 90
# ShipX: 10170.0, ShipY: 6944.0, rot: 0
# PosX: 10237.0, PosY: 6887.0, rot: 0
# N 1
# ShipX: 10170.0, ShipY: 6944.0, rot: 0
# PosX: 10237.0, PosY: 6888.0, rot: 0
# F 2
# ShipX: 10304.0, ShipY: 6832.0, rot: 0
# PosX: 10371.0, PosY: 6776.0, rot: 0
# L 90
# ShipX: 10304.0, ShipY: 6832.0, rot: 0
# PosX: 10360.0, PosY: 6899.0, rot: 0
# F 15
# ShipX: 11144.0, ShipY: 7837.0, rot: 0
# PosX: 11200.0, PosY: 7904.0, rot: 0
# W 3
# ShipX: 11144.0, ShipY: 7837.0, rot: 0
# PosX: 11197.0, PosY: 7904.0, rot: 0
# F 10
# ShipX: 11674.0, ShipY: 8507.0, rot: 0
# PosX: 11727.0, PosY: 8574.0, rot: 0
# R 90
# ShipX: 11674.0, ShipY: 8507.0, rot: 0
# PosX: 11741.0, PosY: 8454.0, rot: 0
# N 3
# ShipX: 11674.0, ShipY: 8507.0, rot: 0
# PosX: 11741.0, PosY: 8457.0, rot: 0
# E 5
# ShipX: 11674.0, ShipY: 8507.0, rot: 0
# PosX: 11746.0, PosY: 8457.0, rot: 0
# N 5
# ShipX: 11674.0, ShipY: 8507.0, rot: 0
# PosX: 11746.0, PosY: 8462.0, rot: 0
# F 57
# ShipX: 15778.0, ShipY: 5942.0, rot: 0
# PosX: 15850.0, PosY: 5897.0, rot: 0
# R 90
# ShipX: 15778.0, ShipY: 5942.0, rot: 0
# PosX: 15733.0, PosY: 5870.0, rot: 0
# W 2
# ShipX: 15778.0, ShipY: 5942.0, rot: 0
# PosX: 15731.0, PosY: 5870.0, rot: 0
# F 83
# ShipX: 11877.0, ShipY: -34.0, rot: 0
# PosX: 11830.0, PosY: -106.0, rot: 0
# F 91
# ShipX: 7600.0, ShipY: -6586.0, rot: 0
# PosX: 7553.0, PosY: -6658.0, rot: 0
# W 5
# ShipX: 7600.0, ShipY: -6586.0, rot: 0
# PosX: 7548.0, PosY: -6658.0, rot: 0
# N 2
# ShipX: 7600.0, ShipY: -6586.0, rot: 0
# PosX: 7548.0, PosY: -6656.0, rot: 0
# R 90
# ShipX: 7600.0, ShipY: -6586.0, rot: 0
# PosX: 7530.0, PosY: -6534.0, rot: 0
# E 4
# ShipX: 7600.0, ShipY: -6586.0, rot: 0
# PosX: 7534.0, PosY: -6534.0, rot: 0
# S 2
# ShipX: 7600.0, ShipY: -6586.0, rot: 0
# PosX: 7534.0, PosY: -6536.0, rot: 0
# L 90
# ShipX: 7600.0, ShipY: -6586.0, rot: 0
# PosX: 7550.0, PosY: -6652.0, rot: 0
# N 2
# ShipX: 7600.0, ShipY: -6586.0, rot: 0
# PosX: 7550.0, PosY: -6650.0, rot: 0
# R 90
# ShipX: 7600.0, ShipY: -6586.0, rot: 0
# PosX: 7536.0, PosY: -6536.0, rot: 0
# S 1
# ShipX: 7600.0, ShipY: -6586.0, rot: 0
# PosX: 7536.0, PosY: -6537.0, rot: 0
# F 49
# ShipX: 4464.0, ShipY: -4185.0, rot: 0
# PosX: 4400.0, PosY: -4136.0, rot: 0
# L 90
# ShipX: 4464.0, ShipY: -4185.0, rot: 0
# PosX: 4415.0, PosY: -4249.0, rot: 0
# E 3
# ShipX: 4464.0, ShipY: -4185.0, rot: 0
# PosX: 4418.0, PosY: -4249.0, rot: 0
# L 180
# ShipX: 4464.0, ShipY: -4185.0, rot: 0
# PosX: 4510.0, PosY: -4121.0, rot: 0
# E 2
# ShipX: 4464.0, ShipY: -4185.0, rot: 0
# PosX: 4512.0, PosY: -4121.0, rot: 0
# F 98
# ShipX: 9168.0, ShipY: 2087.0, rot: 0
# PosX: 9216.0, PosY: 2151.0, rot: 0
# S 1
# ShipX: 9168.0, ShipY: 2087.0, rot: 0
# PosX: 9216.0, PosY: 2150.0, rot: 0
# R 180
# ShipX: 9168.0, ShipY: 2087.0, rot: 0
# PosX: 9120.0, PosY: 2024.0, rot: 0
# F 23
# ShipX: 8064.0, ShipY: 638.0, rot: 0
# PosX: 8016.0, PosY: 575.0, rot: 0
# N 2
# ShipX: 8064.0, ShipY: 638.0, rot: 0
# PosX: 8016.0, PosY: 577.0, rot: 0
# E 2
# ShipX: 8064.0, ShipY: 638.0, rot: 0
# PosX: 8018.0, PosY: 577.0, rot: 0
# F 8
# ShipX: 7696.0, ShipY: 150.0, rot: 0
# PosX: 7650.0, PosY: 89.0, rot: 0
# N 2
# ShipX: 7696.0, ShipY: 150.0, rot: 0
# PosX: 7650.0, PosY: 91.0, rot: 0
# L 90
# ShipX: 7696.0, ShipY: 150.0, rot: 0
# PosX: 7755.0, PosY: 104.0, rot: 0
# E 2
# ShipX: 7696.0, ShipY: 150.0, rot: 0
# PosX: 7757.0, PosY: 104.0, rot: 0
# N 4
# ShipX: 7696.0, ShipY: 150.0, rot: 0
# PosX: 7757.0, PosY: 108.0, rot: 0
# R 90
# ShipX: 7696.0, ShipY: 150.0, rot: 0
# PosX: 7654.0, PosY: 89.0, rot: 0
# F 29
# ShipX: 6478.0, ShipY: -1619.0, rot: 0
# PosX: 6436.0, PosY: -1680.0, rot: 0
# L 90
# ShipX: 6478.0, ShipY: -1619.0, rot: 0
# PosX: 6539.0, PosY: -1661.0, rot: 0
# E 5
# ShipX: 6478.0, ShipY: -1619.0, rot: 0
# PosX: 6544.0, PosY: -1661.0, rot: 0
# S 3
# ShipX: 6478.0, ShipY: -1619.0, rot: 0
# PosX: 6544.0, PosY: -1664.0, rot: 0
# F 92
# ShipX: 12550.0, ShipY: -5759.0, rot: 0
# PosX: 12616.0, PosY: -5804.0, rot: 0
# S 5
# ShipX: 12550.0, ShipY: -5759.0, rot: 0
# PosX: 12616.0, PosY: -5809.0, rot: 0
# F 68
# ShipX: 17038.0, ShipY: -9159.0, rot: 0
# PosX: 17104.0, PosY: -9209.0, rot: 0
# N 1
# ShipX: 17038.0, ShipY: -9159.0, rot: 0
# PosX: 17104.0, PosY: -9208.0, rot: 0
# L 90
# ShipX: 17038.0, ShipY: -9159.0, rot: 0
# PosX: 17087.0, PosY: -9093.0, rot: 0
# S 5
# ShipX: 17038.0, ShipY: -9159.0, rot: 0
# PosX: 17087.0, PosY: -9098.0, rot: 0
# F 73
# ShipX: 20615.0, ShipY: -4706.0, rot: 0
# PosX: 20664.0, PosY: -4645.0, rot: 0
# W 4
# ShipX: 20615.0, ShipY: -4706.0, rot: 0
# PosX: 20660.0, PosY: -4645.0, rot: 0
# L 180
# ShipX: 20615.0, ShipY: -4706.0, rot: 0
# PosX: 20570.0, PosY: -4767.0, rot: 0
# S 1
# ShipX: 20615.0, ShipY: -4706.0, rot: 0
# PosX: 20570.0, PosY: -4768.0, rot: 0
# R 180
# ShipX: 20615.0, ShipY: -4706.0, rot: 0
# PosX: 20660.0, PosY: -4644.0, rot: 0
# F 74
# ShipX: 23945.0, ShipY: -118.0, rot: 0
# PosX: 23990.0, PosY: -56.0, rot: 0
# R 90
# ShipX: 23945.0, ShipY: -118.0, rot: 0
# PosX: 24007.0, PosY: -163.0, rot: 0
# F 27
# ShipX: 25619.0, ShipY: -1333.0, rot: 0
# PosX: 25681.0, PosY: -1378.0, rot: 0
# R 180
# ShipX: 25619.0, ShipY: -1333.0, rot: 0
# PosX: 25557.0, PosY: -1288.0, rot: 0
# R 90
# ShipX: 25619.0, ShipY: -1333.0, rot: 0
# PosX: 25664.0, PosY: -1271.0, rot: 0
# F 88
# ShipX: 29579.0, ShipY: 4123.0, rot: 0
# PosX: 29624.0, PosY: 4185.0, rot: 0
# R 270
# ShipX: 29579.0, ShipY: 4123.0, rot: 0
# PosX: 29517.0, PosY: 4168.0, rot: 0
# S 1
# ShipX: 29579.0, ShipY: 4123.0, rot: 0
# PosX: 29517.0, PosY: 4167.0, rot: 0
# W 1
# ShipX: 29579.0, ShipY: 4123.0, rot: 0
# PosX: 29516.0, PosY: 4167.0, rot: 0
# F 73
# ShipX: 24980.0, ShipY: 7335.0, rot: 0
# PosX: 24917.0, PosY: 7379.0, rot: 0
# W 1
# ShipX: 24980.0, ShipY: 7335.0, rot: 0
# PosX: 24916.0, PosY: 7379.0, rot: 0
# S 5
# ShipX: 24980.0, ShipY: 7335.0, rot: 0
# PosX: 24916.0, PosY: 7374.0, rot: 0
# L 90
# ShipX: 24980.0, ShipY: 7335.0, rot: 0
# PosX: 24941.0, PosY: 7271.0, rot: 0
# N 5
# ShipX: 24980.0, ShipY: 7335.0, rot: 0
# PosX: 24941.0, PosY: 7276.0, rot: 0
# R 90
# ShipX: 24980.0, ShipY: 7335.0, rot: 0
# PosX: 24921.0, PosY: 7374.0, rot: 0
# F 50
# ShipX: 22030.0, ShipY: 9285.0, rot: 0
# PosX: 21971.0, PosY: 9324.0, rot: 0
# E 2
# ShipX: 22030.0, ShipY: 9285.0, rot: 0
# PosX: 21973.0, PosY: 9324.0, rot: 0
# R 90
# ShipX: 22030.0, ShipY: 9285.0, rot: 0
# PosX: 22069.0, PosY: 9342.0, rot: 0
# W 3
# ShipX: 22030.0, ShipY: 9285.0, rot: 0
# PosX: 22066.0, PosY: 9342.0, rot: 0
# F 23
# ShipX: 22858.0, ShipY: 10596.0, rot: 0
# PosX: 22894.0, PosY: 10653.0, rot: 0
# L 90
# ShipX: 22858.0, ShipY: 10596.0, rot: 0
# PosX: 22801.0, PosY: 10632.0, rot: 0
# W 2
# ShipX: 22858.0, ShipY: 10596.0, rot: 0
# PosX: 22799.0, PosY: 10632.0, rot: 0
# N 1
# ShipX: 22858.0, ShipY: 10596.0, rot: 0
# PosX: 22799.0, PosY: 10633.0, rot: 0
# E 2
# ShipX: 22858.0, ShipY: 10596.0, rot: 0
# PosX: 22801.0, PosY: 10633.0, rot: 0
# N 2
# ShipX: 22858.0, ShipY: 10596.0, rot: 0
# PosX: 22801.0, PosY: 10635.0, rot: 0
# F 56
# ShipX: 19666.0, ShipY: 12780.0, rot: 0
# PosX: 19609.0, PosY: 12819.0, rot: 0
# L 90
# ShipX: 19666.0, ShipY: 12780.0, rot: 0
# PosX: 19627.0, PosY: 12723.0, rot: 0
# F 22
# ShipX: 18808.0, ShipY: 11526.0, rot: 0
# PosX: 18769.0, PosY: 11469.0, rot: 0
# E 5
# ShipX: 18808.0, ShipY: 11526.0, rot: 0
# PosX: 18774.0, PosY: 11469.0, rot: 0
# F 46
# ShipX: 17244.0, ShipY: 8904.0, rot: 0
# PosX: 17210.0, PosY: 8847.0, rot: 0
# S 2
# ShipX: 17244.0, ShipY: 8904.0, rot: 0
# PosX: 17210.0, PosY: 8845.0, rot: 0
# L 180
# ShipX: 17244.0, ShipY: 8904.0, rot: 0
# PosX: 17278.0, PosY: 8963.0, rot: 0
# E 4
# ShipX: 17244.0, ShipY: 8904.0, rot: 0
# PosX: 17282.0, PosY: 8963.0, rot: 0
# R 90
# ShipX: 17244.0, ShipY: 8904.0, rot: 0
# PosX: 17303.0, PosY: 8866.0, rot: 0
# F 10
# ShipX: 17834.0, ShipY: 8524.0, rot: 0
# PosX: 17893.0, PosY: 8486.0, rot: 0
# W 2
# ShipX: 17834.0, ShipY: 8524.0, rot: 0
# PosX: 17891.0, PosY: 8486.0, rot: 0
# R 90
# ShipX: 17834.0, ShipY: 8524.0, rot: 0
# PosX: 17796.0, PosY: 8467.0, rot: 0
# E 5
# ShipX: 17834.0, ShipY: 8524.0, rot: 0
# PosX: 17801.0, PosY: 8467.0, rot: 0
# L 270
# ShipX: 17834.0, ShipY: 8524.0, rot: 0
# PosX: 17777.0, PosY: 8557.0, rot: 0
# S 4
# ShipX: 17834.0, ShipY: 8524.0, rot: 0
# PosX: 17777.0, PosY: 8553.0, rot: 0
# F 55
# ShipX: 14699.0, ShipY: 10119.0, rot: 0
# PosX: 14642.0, PosY: 10148.0, rot: 0
# R 90
# ShipX: 14699.0, ShipY: 10119.0, rot: 0
# PosX: 14728.0, PosY: 10176.0, rot: 0
# F 17
# ShipX: 15192.0, ShipY: 11088.0, rot: 0
# PosX: 15221.0, PosY: 11145.0, rot: 0
# R 90
# ShipX: 15192.0, ShipY: 11088.0, rot: 0
# PosX: 15249.0, PosY: 11059.0, rot: 0
# F 8
# ShipX: 15648.0, ShipY: 10856.0, rot: 0
# PosX: 15705.0, PosY: 10827.0, rot: 0
# L 180
# ShipX: 15648.0, ShipY: 10856.0, rot: 0
# PosX: 15591.0, PosY: 10885.0, rot: 0
# F 25
# ShipX: 14223.0, ShipY: 11581.0, rot: 0
# PosX: 14166.0, PosY: 11610.0, rot: 0
# E 4
# ShipX: 14223.0, ShipY: 11581.0, rot: 0
# PosX: 14170.0, PosY: 11610.0, rot: 0
# S 2
# ShipX: 14223.0, ShipY: 11581.0, rot: 0
# PosX: 14170.0, PosY: 11608.0, rot: 0
# E 1
# ShipX: 14223.0, ShipY: 11581.0, rot: 0
# PosX: 14171.0, PosY: 11608.0, rot: 0
# S 1
# ShipX: 14223.0, ShipY: 11581.0, rot: 0
# PosX: 14171.0, PosY: 11607.0, rot: 0
# F 35
# ShipX: 12403.0, ShipY: 12491.0, rot: 0
# PosX: 12351.0, PosY: 12517.0, rot: 0
# N 5
# ShipX: 12403.0, ShipY: 12491.0, rot: 0
# PosX: 12351.0, PosY: 12522.0, rot: 0
# W 5
# ShipX: 12403.0, ShipY: 12491.0, rot: 0
# PosX: 12346.0, PosY: 12522.0, rot: 0
# N 3
# ShipX: 12403.0, ShipY: 12491.0, rot: 0
# PosX: 12346.0, PosY: 12525.0, rot: 0
# F 79
# ShipX: 7900.0, ShipY: 15177.0, rot: 0
# PosX: 7843.0, PosY: 15211.0, rot: 0
# N 1
# ShipX: 7900.0, ShipY: 15177.0, rot: 0
# PosX: 7843.0, PosY: 15212.0, rot: 0
# R 90
# ShipX: 7900.0, ShipY: 15177.0, rot: 0
# PosX: 7935.0, PosY: 15234.0, rot: 0
# E 1
# ShipX: 7900.0, ShipY: 15177.0, rot: 0
# PosX: 7936.0, PosY: 15234.0, rot: 0
# F 32
# ShipX: 9052.0, ShipY: 17001.0, rot: 0
# PosX: 9088.0, PosY: 17058.0, rot: 0
# R 90
# ShipX: 9052.0, ShipY: 17001.0, rot: 0
# PosX: 9109.0, PosY: 16965.0, rot: 0
# F 87
# ShipX: 14011.0, ShipY: 13869.0, rot: 0
# PosX: 14068.0, PosY: 13833.0, rot: 0
# N 2
# ShipX: 14011.0, ShipY: 13869.0, rot: 0
# PosX: 14068.0, PosY: 13835.0, rot: 0
# R 180
# ShipX: 14011.0, ShipY: 13869.0, rot: 0
# PosX: 13954.0, PosY: 13903.0, rot: 0
# L 180
# ShipX: 14011.0, ShipY: 13869.0, rot: 0
# PosX: 14068.0, PosY: 13835.0, rot: 0
# F 38
# ShipX: 16177.0, ShipY: 12577.0, rot: 0
# PosX: 16234.0, PosY: 12543.0, rot: 0
# L 90
# ShipX: 16177.0, ShipY: 12577.0, rot: 0
# PosX: 16211.0, PosY: 12634.0, rot: 0
# S 1
# ShipX: 16177.0, ShipY: 12577.0, rot: 0
# PosX: 16211.0, PosY: 12633.0, rot: 0
# L 270
# ShipX: 16177.0, ShipY: 12577.0, rot: 0
# PosX: 16233.0, PosY: 12543.0, rot: 0
# S 5
# ShipX: 16177.0, ShipY: 12577.0, rot: 0
# PosX: 16233.0, PosY: 12538.0, rot: 0
# F 63
# ShipX: 19705.0, ShipY: 10120.0, rot: 0
# PosX: 19761.0, PosY: 10081.0, rot: 0
# L 180
# ShipX: 19705.0, ShipY: 10120.0, rot: 0
# PosX: 19649.0, PosY: 10159.0, rot: 0
# F 50
# ShipX: 16905.0, ShipY: 12070.0, rot: 0
# PosX: 16849.0, PosY: 12109.0, rot: 0
# W 1
# ShipX: 16905.0, ShipY: 12070.0, rot: 0
# PosX: 16848.0, PosY: 12109.0, rot: 0
# F 23
# ShipX: 15594.0, ShipY: 12967.0, rot: 0
# PosX: 15537.0, PosY: 13006.0, rot: 0
# S 2
# ShipX: 15594.0, ShipY: 12967.0, rot: 0
# PosX: 15537.0, PosY: 13004.0, rot: 0
# E 2
# ShipX: 15594.0, ShipY: 12967.0, rot: 0
# PosX: 15539.0, PosY: 13004.0, rot: 0
# F 30
# ShipX: 13944.0, ShipY: 14077.0, rot: 0
# PosX: 13889.0, PosY: 14114.0, rot: 0
# E 3
# ShipX: 13944.0, ShipY: 14077.0, rot: 0
# PosX: 13892.0, PosY: 14114.0, rot: 0
# L 90
# ShipX: 13944.0, ShipY: 14077.0, rot: 0
# PosX: 13907.0, PosY: 14025.0, rot: 0
# F 79
# ShipX: 11021.0, ShipY: 9969.0, rot: 0
# PosX: 10984.0, PosY: 9917.0, rot: 0
# R 180
# ShipX: 11021.0, ShipY: 9969.0, rot: 0
# PosX: 11058.0, PosY: 10021.0, rot: 0
# F 90
# ShipX: 14351.0, ShipY: 14649.0, rot: 0
# PosX: 14388.0, PosY: 14701.0, rot: 0
# L 180
# ShipX: 14351.0, ShipY: 14649.0, rot: 0
# PosX: 14314.0, PosY: 14597.0, rot: 0
# F 81
# ShipX: 11354.0, ShipY: 10437.0, rot: 0
# PosX: 11317.0, PosY: 10385.0, rot: 0
# R 90
# ShipX: 11354.0, ShipY: 10437.0, rot: 0
# PosX: 11302.0, PosY: 10474.0, rot: 0
# F 72
# ShipX: 7610.0, ShipY: 13101.0, rot: 0
# PosX: 7558.0, PosY: 13138.0, rot: 0
# R 180
# ShipX: 7610.0, ShipY: 13101.0, rot: 0
# PosX: 7662.0, PosY: 13064.0, rot: 0
# E 4
# ShipX: 7610.0, ShipY: 13101.0, rot: 0
# PosX: 7666.0, PosY: 13064.0, rot: 0
# N 3
# ShipX: 7610.0, ShipY: 13101.0, rot: 0
# PosX: 7666.0, PosY: 13067.0, rot: 0
# W 3
# ShipX: 7610.0, ShipY: 13101.0, rot: 0
# PosX: 7663.0, PosY: 13067.0, rot: 0
# R 90
# ShipX: 7610.0, ShipY: 13101.0, rot: 0
# PosX: 7576.0, PosY: 13048.0, rot: 0
# E 5
# ShipX: 7610.0, ShipY: 13101.0, rot: 0
# PosX: 7581.0, PosY: 13048.0, rot: 0
# R 90
# ShipX: 7610.0, ShipY: 13101.0, rot: 0
# PosX: 7557.0, PosY: 13130.0, rot: 0
# F 81
# ShipX: 3317.0, ShipY: 15450.0, rot: 0
# PosX: 3264.0, PosY: 15479.0, rot: 0
# S 3
# ShipX: 3317.0, ShipY: 15450.0, rot: 0
# PosX: 3264.0, PosY: 15476.0, rot: 0
# F 66
# ShipX: -181.0, ShipY: 17166.0, rot: 0
# PosX: -234.0, PosY: 17192.0, rot: 0
# S 5
# ShipX: -181.0, ShipY: 17166.0, rot: 0
# PosX: -234.0, PosY: 17187.0, rot: 0
# F 83
# ShipX: -4580.0, ShipY: 18909.0, rot: 0
# PosX: -4633.0, PosY: 18930.0, rot: 0
# L 90
# ShipX: -4580.0, ShipY: 18909.0, rot: 0
# PosX: -4601.0, PosY: 18856.0, rot: 0
# F 15
# ShipX: -4895.0, ShipY: 18114.0, rot: 0
# PosX: -4916.0, PosY: 18061.0, rot: 0
# N 5
# ShipX: -4895.0, ShipY: 18114.0, rot: 0
# PosX: -4916.0, PosY: 18066.0, rot: 0
# F 16
# ShipX: -5231.0, ShipY: 17346.0, rot: 0
# PosX: -5252.0, PosY: 17298.0, rot: 0
# L 270
# ShipX: -5231.0, ShipY: 17346.0, rot: 0
# PosX: -5279.0, PosY: 17367.0, rot: 0
# S 3
# ShipX: -5231.0, ShipY: 17346.0, rot: 0
# PosX: -5279.0, PosY: 17364.0, rot: 0
# L 270
# ShipX: -5231.0, ShipY: 17346.0, rot: 0
# PosX: -5213.0, PosY: 17394.0, rot: 0
# S 3
# ShipX: -5231.0, ShipY: 17346.0, rot: 0
# PosX: -5213.0, PosY: 17391.0, rot: 0
# L 90
# ShipX: -5231.0, ShipY: 17346.0, rot: 0
# PosX: -5276.0, PosY: 17364.0, rot: 0
# N 5
# ShipX: -5231.0, ShipY: 17346.0, rot: 0
# PosX: -5276.0, PosY: 17369.0, rot: 0
# E 2
# ShipX: -5231.0, ShipY: 17346.0, rot: 0
# PosX: -5274.0, PosY: 17369.0, rot: 0
# F 60
# ShipX: -7811.0, ShipY: 18726.0, rot: 0
# PosX: -7854.0, PosY: 18749.0, rot: 0
# W 2
# ShipX: -7811.0, ShipY: 18726.0, rot: 0
# PosX: -7856.0, PosY: 18749.0, rot: 0
# S 4
# ShipX: -7811.0, ShipY: 18726.0, rot: 0
# PosX: -7856.0, PosY: 18745.0, rot: 0
# E 1
# ShipX: -7811.0, ShipY: 18726.0, rot: 0
# PosX: -7855.0, PosY: 18745.0, rot: 0
# R 180
# ShipX: -7811.0, ShipY: 18726.0, rot: 0
# PosX: -7767.0, PosY: 18707.0, rot: 0
# W 2
# ShipX: -7811.0, ShipY: 18726.0, rot: 0
# PosX: -7769.0, PosY: 18707.0, rot: 0
# F 28
# ShipX: -6635.0, ShipY: 18194.0, rot: 0
# PosX: -6593.0, PosY: 18175.0, rot: 0
# W 4
# ShipX: -6635.0, ShipY: 18194.0, rot: 0
# PosX: -6597.0, PosY: 18175.0, rot: 0
# R 90
# ShipX: -6635.0, ShipY: 18194.0, rot: 0
# PosX: -6654.0, PosY: 18156.0, rot: 0
# N 3
# ShipX: -6635.0, ShipY: 18194.0, rot: 0
# PosX: -6654.0, PosY: 18159.0, rot: 0
# W 3
# ShipX: -6635.0, ShipY: 18194.0, rot: 0
# PosX: -6657.0, PosY: 18159.0, rot: 0
# F 48
# ShipX: -7691.0, ShipY: 16514.0, rot: 0
# PosX: -7713.0, PosY: 16479.0, rot: 0
# W 2
# ShipX: -7691.0, ShipY: 16514.0, rot: 0
# PosX: -7715.0, PosY: 16479.0, rot: 0
# S 5
# ShipX: -7691.0, ShipY: 16514.0, rot: 0
# PosX: -7715.0, PosY: 16474.0, rot: 0
# F 2
# ShipX: -7739.0, ShipY: 16434.0, rot: 0
# PosX: -7763.0, PosY: 16394.0, rot: 0
# R 90
# ShipX: -7739.0, ShipY: 16434.0, rot: 0
# PosX: -7779.0, PosY: 16458.0, rot: 0
# F 47
# ShipX: -9619.0, ShipY: 17562.0, rot: 0
# PosX: -9659.0, PosY: 17586.0, rot: 0
# S 5
# ShipX: -9619.0, ShipY: 17562.0, rot: 0
# PosX: -9659.0, PosY: 17581.0, rot: 0
# F 11
# ShipX: -10059.0, ShipY: 17771.0, rot: 0
# PosX: -10099.0, PosY: 17790.0, rot: 0
# S 5
# ShipX: -10059.0, ShipY: 17771.0, rot: 0
# PosX: -10099.0, PosY: 17785.0, rot: 0
# E 2
# ShipX: -10059.0, ShipY: 17771.0, rot: 0
# PosX: -10097.0, PosY: 17785.0, rot: 0
# N 2
# ShipX: -10059.0, ShipY: 17771.0, rot: 0
# PosX: -10097.0, PosY: 17787.0, rot: 0
# F 93
# ShipX: -13593.0, ShipY: 19259.0, rot: 0
# PosX: -13631.0, PosY: 19275.0, rot: 0
# S 2
# ShipX: -13593.0, ShipY: 19259.0, rot: 0
# PosX: -13631.0, PosY: 19273.0, rot: 0
# E 4
# ShipX: -13593.0, ShipY: 19259.0, rot: 0
# PosX: -13627.0, PosY: 19273.0, rot: 0
# F 23
# ShipX: -14375.0, ShipY: 19581.0, rot: 0
# PosX: -14409.0, PosY: 19595.0, rot: 0
# E 4
# ShipX: -14375.0, ShipY: 19581.0, rot: 0
# PosX: -14405.0, PosY: 19595.0, rot: 0
# S 1
# ShipX: -14375.0, ShipY: 19581.0, rot: 0
# PosX: -14405.0, PosY: 19594.0, rot: 0
# L 90
# ShipX: -14375.0, ShipY: 19581.0, rot: 0
# PosX: -14388.0, PosY: 19551.0, rot: 0
# F 87
# ShipX: -15506.0, ShipY: 16971.0, rot: 0
# PosX: -15519.0, PosY: 16941.0, rot: 0
# L 180
# ShipX: -15506.0, ShipY: 16971.0, rot: 0
# PosX: -15493.0, PosY: 17001.0, rot: 0
# N 4
# ShipX: -15506.0, ShipY: 16971.0, rot: 0
# PosX: -15493.0, PosY: 17005.0, rot: 0
# W 5
# ShipX: -15506.0, ShipY: 16971.0, rot: 0
# PosX: -15498.0, PosY: 17005.0, rot: 0
# N 5
# ShipX: -15506.0, ShipY: 16971.0, rot: 0
# PosX: -15498.0, PosY: 17010.0, rot: 0
# R 180
# ShipX: -15506.0, ShipY: 16971.0, rot: 0
# PosX: -15514.0, PosY: 16932.0, rot: 0
# R 90
# ShipX: -15506.0, ShipY: 16971.0, rot: 0
# PosX: -15545.0, PosY: 16979.0, rot: 0
# S 5
# ShipX: -15506.0, ShipY: 16971.0, rot: 0
# PosX: -15545.0, PosY: 16974.0, rot: 0
# F 65
# ShipX: -18041.0, ShipY: 17166.0, rot: 0
# PosX: -18080.0, PosY: 17169.0, rot: 0
# E 5
# ShipX: -18041.0, ShipY: 17166.0, rot: 0
# PosX: -18075.0, PosY: 17169.0, rot: 0
# F 51
# ShipX: -19775.0, ShipY: 17319.0, rot: 0
# PosX: -19809.0, PosY: 17322.0, rot: 0
# E 5
# ShipX: -19775.0, ShipY: 17319.0, rot: 0
# PosX: -19804.0, PosY: 17322.0, rot: 0
# F 65
# ShipX: -21660.0, ShipY: 17514.0, rot: 0
# PosX: -21689.0, PosY: 17517.0, rot: 0
# L 90
# ShipX: -21660.0, ShipY: 17514.0, rot: 0
# PosX: -21663.0, PosY: 17485.0, rot: 0
# S 4
# ShipX: -21660.0, ShipY: 17514.0, rot: 0
# PosX: -21663.0, PosY: 17481.0, rot: 0
# W 3
# ShipX: -21660.0, ShipY: 17514.0, rot: 0
# PosX: -21666.0, PosY: 17481.0, rot: 0
# L 180
# ShipX: -21660.0, ShipY: 17514.0, rot: 0
# PosX: -21654.0, PosY: 17547.0, rot: 0
# W 1
# ShipX: -21660.0, ShipY: 17514.0, rot: 0
# PosX: -21655.0, PosY: 17547.0, rot: 0
# W 2
# ShipX: -21660.0, ShipY: 17514.0, rot: 0
# PosX: -21657.0, PosY: 17547.0, rot: 0
# E 4
# ShipX: -21660.0, ShipY: 17514.0, rot: 0
# PosX: -21653.0, PosY: 17547.0, rot: 0
# R 270
# ShipX: -21660.0, ShipY: 17514.0, rot: 0
# PosX: -21693.0, PosY: 17521.0, rot: 0
# N 4
# ShipX: -21660.0, ShipY: 17514.0, rot: 0
# PosX: -21693.0, PosY: 17525.0, rot: 0
# F 86
# ShipX: -24498.0, ShipY: 18460.0, rot: 0
# PosX: -24531.0, PosY: 18471.0, rot: 0
# R 90
# ShipX: -24498.0, ShipY: 18460.0, rot: 0
# PosX: -24487.0, PosY: 18493.0, rot: 0
# L 90
# ShipX: -24498.0, ShipY: 18460.0, rot: 0
# PosX: -24531.0, PosY: 18471.0, rot: 0
# F 9
# ShipX: -24795.0, ShipY: 18559.0, rot: 0
# PosX: -24828.0, PosY: 18570.0, rot: 0
# F 76
# ShipX: -27303.0, ShipY: 19395.0, rot: 0
# PosX: -27336.0, PosY: 19406.0, rot: 0
# N 4
# ShipX: -27303.0, ShipY: 19395.0, rot: 0
# PosX: -27336.0, PosY: 19410.0, rot: 0
# E 4
# ShipX: -27303.0, ShipY: 19395.0, rot: 0
# PosX: -27332.0, PosY: 19410.0, rot: 0
# N 4
# ShipX: -27303.0, ShipY: 19395.0, rot: 0
# PosX: -27332.0, PosY: 19414.0, rot: 0
# R 90
# ShipX: -27303.0, ShipY: 19395.0, rot: 0
# PosX: -27284.0, PosY: 19424.0, rot: 0
# F 40
# ShipX: -26543.0, ShipY: 20555.0, rot: 0
# PosX: -26524.0, PosY: 20584.0, rot: 0
# E 5
# ShipX: -26543.0, ShipY: 20555.0, rot: 0
# PosX: -26519.0, PosY: 20584.0, rot: 0
# S 1
# ShipX: -26543.0, ShipY: 20555.0, rot: 0
# PosX: -26519.0, PosY: 20583.0, rot: 0
# W 3
# ShipX: -26543.0, ShipY: 20555.0, rot: 0
# PosX: -26522.0, PosY: 20583.0, rot: 0
# F 22
# ShipX: -26081.0, ShipY: 21171.0, rot: 0
# PosX: -26060.0, PosY: 21199.0, rot: 0
# W 2
# ShipX: -26081.0, ShipY: 21171.0, rot: 0
# PosX: -26062.0, PosY: 21199.0, rot: 0
# L 90
# ShipX: -26081.0, ShipY: 21171.0, rot: 0
# PosX: -26109.0, PosY: 21190.0, rot: 0
# F 51
# ShipX: -27509.0, ShipY: 22140.0, rot: 0
# PosX: -27537.0, PosY: 22159.0, rot: 0
# W 1
# ShipX: -27509.0, ShipY: 22140.0, rot: 0
# PosX: -27538.0, PosY: 22159.0, rot: 0
# E 1
# ShipX: -27509.0, ShipY: 22140.0, rot: 0
# PosX: -27537.0, PosY: 22159.0, rot: 0
# S 2
# ShipX: -27509.0, ShipY: 22140.0, rot: 0
# PosX: -27537.0, PosY: 22157.0, rot: 0
# F 27
# ShipX: -28265.0, ShipY: 22599.0, rot: 0
# PosX: -28293.0, PosY: 22616.0, rot: 0
# S 5
# ShipX: -28265.0, ShipY: 22599.0, rot: 0
# PosX: -28293.0, PosY: 22611.0, rot: 0
# R 90
# ShipX: -28265.0, ShipY: 22599.0, rot: 0
# PosX: -28253.0, PosY: 22627.0, rot: 0
# R 270
# ShipX: -28265.0, ShipY: 22599.0, rot: 0
# PosX: -28293.0, PosY: 22611.0, rot: 0
# R 90
# ShipX: -28265.0, ShipY: 22599.0, rot: 0
# PosX: -28253.0, PosY: 22627.0, rot: 0
# F 71
# ShipX: -27413.0, ShipY: 24587.0, rot: 0
# PosX: -27401.0, PosY: 24615.0, rot: 0
# R 90
# ShipX: -27413.0, ShipY: 24587.0, rot: 0
# PosX: -27385.0, PosY: 24575.0, rot: 0
# W 4
# ShipX: -27413.0, ShipY: 24587.0, rot: 0
# PosX: -27389.0, PosY: 24575.0, rot: 0
# R 90
# ShipX: -27413.0, ShipY: 24587.0, rot: 0
# PosX: -27425.0, PosY: 24563.0, rot: 0
# W 1
# ShipX: -27413.0, ShipY: 24587.0, rot: 0
# PosX: -27426.0, PosY: 24563.0, rot: 0
# N 4
# ShipX: -27413.0, ShipY: 24587.0, rot: 0
# PosX: -27426.0, PosY: 24567.0, rot: 0
# L 90
# ShipX: -27413.0, ShipY: 24587.0, rot: 0
# PosX: -27393.0, PosY: 24574.0, rot: 0
# E 2
# ShipX: -27413.0, ShipY: 24587.0, rot: 0
# PosX: -27391.0, PosY: 24574.0, rot: 0
# E 1
# ShipX: -27413.0, ShipY: 24587.0, rot: 0
# PosX: -27390.0, PosY: 24574.0, rot: 0
# F 61
# ShipX: -26010.0, ShipY: 23794.0, rot: 0
# PosX: -25987.0, PosY: 23781.0, rot: 0
# W 1
# ShipX: -26010.0, ShipY: 23794.0, rot: 0
# PosX: -25988.0, PosY: 23781.0, rot: 0
# S 5
# ShipX: -26010.0, ShipY: 23794.0, rot: 0
# PosX: -25988.0, PosY: 23776.0, rot: 0
# E 2
# ShipX: -26010.0, ShipY: 23794.0, rot: 0
# PosX: -25986.0, PosY: 23776.0, rot: 0
# E 4
# ShipX: -26010.0, ShipY: 23794.0, rot: 0
# PosX: -25982.0, PosY: 23776.0, rot: 0
# F 10
# ShipX: -25730.0, ShipY: 23614.0, rot: 0
# PosX: -25702.0, PosY: 23596.0, rot: 0
# L 90
# ShipX: -25730.0, ShipY: 23614.0, rot: 0
# PosX: -25712.0, PosY: 23642.0, rot: 0
# N 2
# ShipX: -25730.0, ShipY: 23614.0, rot: 0
# PosX: -25712.0, PosY: 23644.0, rot: 0
# F 3
# ShipX: -25676.0, ShipY: 23704.0, rot: 0
# PosX: -25658.0, PosY: 23734.0, rot: 0
# R 90
# ShipX: -25676.0, ShipY: 23704.0, rot: 0
# PosX: -25646.0, PosY: 23686.0, rot: 0
# F 7
# ShipX: -25466.0, ShipY: 23578.0, rot: 0
# PosX: -25436.0, PosY: 23560.0, rot: 0
# L 90
# ShipX: -25466.0, ShipY: 23578.0, rot: 0
# PosX: -25448.0, PosY: 23608.0, rot: 0
# F 56
# ShipX: -24458.0, ShipY: 25258.0, rot: 0
# PosX: -24440.0, PosY: 25288.0, rot: 0
# N 1
# ShipX: -24458.0, ShipY: 25258.0, rot: 0
# PosX: -24440.0, PosY: 25289.0, rot: 0
# R 270
# ShipX: -24458.0, ShipY: 25258.0, rot: 0
# PosX: -24489.0, PosY: 25276.0, rot: 0
# F 70
# ShipX: -26628.0, ShipY: 26518.0, rot: 0
# PosX: -26659.0, PosY: 26536.0, rot: 0
# F 71
# ShipX: -28829.0, ShipY: 27796.0, rot: 0
# PosX: -28860.0, PosY: 27814.0, rot: 0
# N 3
# ShipX: -28829.0, ShipY: 27796.0, rot: 0
# PosX: -28860.0, PosY: 27817.0, rot: 0
# F 96
# ShipX: -31805.0, ShipY: 29812.0, rot: 0
# PosX: -31836.0, PosY: 29833.0, rot: 0
# R 90
# ShipX: -31805.0, ShipY: 29812.0, rot: 0
# PosX: -31784.0, PosY: 29843.0, rot: 0
# F 56
# ShipX: -30629.0, ShipY: 31548.0, rot: 0
# PosX: -30608.0, PosY: 31579.0, rot: 0
# S 4
# ShipX: -30629.0, ShipY: 31548.0, rot: 0
# PosX: -30608.0, PosY: 31575.0, rot: 0
# F 96
# ShipX: -28613.0, ShipY: 34140.0, rot: 0
# PosX: -28592.0, PosY: 34167.0, rot: 0
# S 5
# ShipX: -28613.0, ShipY: 34140.0, rot: 0
# PosX: -28592.0, PosY: 34162.0, rot: 0
# W 5
# ShipX: -28613.0, ShipY: 34140.0, rot: 0
# PosX: -28597.0, PosY: 34162.0, rot: 0
# N 4
# ShipX: -28613.0, ShipY: 34140.0, rot: 0
# PosX: -28597.0, PosY: 34166.0, rot: 0
# E 2
# ShipX: -28613.0, ShipY: 34140.0, rot: 0
# PosX: -28595.0, PosY: 34166.0, rot: 0
# F 90
# ShipX: -26993.0, ShipY: 36480.0, rot: 0
# PosX: -26975.0, PosY: 36506.0, rot: 0
# S 5
# ShipX: -26993.0, ShipY: 36480.0, rot: 0
# PosX: -26975.0, PosY: 36501.0, rot: 0
# R 180
# ShipX: -26993.0, ShipY: 36480.0, rot: 0
# PosX: -27011.0, PosY: 36459.0, rot: 0
# F 81
# ShipX: -28451.0, ShipY: 34779.0, rot: 0
# PosX: -28469.0, PosY: 34758.0, rot: 0
# E 1
# ShipX: -28451.0, ShipY: 34779.0, rot: 0
# PosX: -28468.0, PosY: 34758.0, rot: 0
# N 4
# ShipX: -28451.0, ShipY: 34779.0, rot: 0
# PosX: -28468.0, PosY: 34762.0, rot: 0
# L 90
# ShipX: -28451.0, ShipY: 34779.0, rot: 0
# PosX: -28434.0, PosY: 34762.0, rot: 0
# S 2
# ShipX: -28451.0, ShipY: 34779.0, rot: 0
# PosX: -28434.0, PosY: 34760.0, rot: 0
# L 180
# ShipX: -28451.0, ShipY: 34779.0, rot: 0
# PosX: -28468.0, PosY: 34798.0, rot: 0
# E 5
# ShipX: -28451.0, ShipY: 34779.0, rot: 0
# PosX: -28463.0, PosY: 34798.0, rot: 0
# R 90
# ShipX: -28451.0, ShipY: 34779.0, rot: 0
# PosX: -28432.0, PosY: 34791.0, rot: 0
# S 4
# ShipX: -28451.0, ShipY: 34779.0, rot: 0
# PosX: -28432.0, PosY: 34787.0, rot: 0
# F 60
# ShipX: -27311.0, ShipY: 35259.0, rot: 0
# PosX: -27292.0, PosY: 35267.0, rot: 0
# S 4
# ShipX: -27311.0, ShipY: 35259.0, rot: 0
# PosX: -27292.0, PosY: 35263.0, rot: 0
# W 3
# ShipX: -27311.0, ShipY: 35259.0, rot: 0
# PosX: -27295.0, PosY: 35263.0, rot: 0
# F 3
# ShipX: -27263.0, ShipY: 35271.0, rot: 0
# PosX: -27247.0, PosY: 35275.0, rot: 0
# E 5
# ShipX: -27263.0, ShipY: 35271.0, rot: 0
# PosX: -27242.0, PosY: 35275.0, rot: 0
# F 54
# ShipX: -26129.0, ShipY: 35487.0, rot: 0
# PosX: -26108.0, PosY: 35491.0, rot: 0
# Manhattan: 61616.0
